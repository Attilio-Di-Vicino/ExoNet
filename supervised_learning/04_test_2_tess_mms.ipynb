# %% [markdown]
# # Test 2 on TESS data
#
# Test 2 on TESS data aims to examine the performance of a random forest without considering the follow-up characteristics

# %%
import pandas as pd
import sys
import os

# Added paths to import modules
sys.path.insert(0, os.path.abspath('../'))

# import custom modules
from data_processing.distribution import (plot_class_distribution, plot_feature_importances,
                                          plot_scatter_feature_distributions, 
                                          plot_hist_feature_distributions,
                                          plot_hist_feature_distributions_0_1,
                                          compute_train_0_1)
from data_processing.data_analysis import (compute_all_columns_nan, print_nan_numbers_for_features,
                                           threshold_delete_nan)
from data_processing.data_balancing import smote_oversampling
from data_processing.data_scaling import plot_top_7_difference, data_scaling_normalization
from data_processing.features_prosessing import remove_non_numeric_columns, rows_id_nan, remove_nan_label
from data_processing.knn_imputer import k_nearest_neighbors_imputer
from data_processing.replace_disposition import replace_label
from dimensionality_reduction.features_selection import compute_feature_importance, feature_selection_rfc
from model_selection.grid_search import grid_search_param_optimization
from utils.mission import Mission
from utils.plot_style import PlotStyle
from utils.util import print_count_nan, print_feature_importance

# %% [markdown]
# # Read Data
#
# read the csv file taken from:
# 1. TESS: ExoFOP https://exofop.ipac.caltech.edu/tess/view_toi.php

# %%
tess_data = pd.read_csv('../data/raw_data/tess_exofop.csv')
print('Shape of ExoFOP TESS data:', tess_data.shape)
_ = print_count_nan(data=tess_data, name='TESS')
# Out:
# Shape of ExoFOP TESS data: (6977, 62)
# Number of NaN values in TESS: 38201 out of 432574: 8.83%

# %% [markdown]
# # Replace Label
#
# In the data initially there is an disposition that includes 3 or more classes.
#
# TESS: Disposizione TFOPWG
# 1. APC = Candidato Planetario Ambiguo
# 2. CP = Pianeta Confermato
# 3. FA = Falso Allarme
# 4. FP = Falso Positivo
# 5. KP = Pianeta Conosciuto
# 6. PC = Candidato Planetario
#
# with the aim of making a binary classifier we use the following procedure to replace:
# 1. KP, CP, PC with the label: 1
# 2. APC, FA, FP with the label: 0
#
# NASA Exoplanet Archive documentation: https://exoplanetarchive.ipac.caltech.edu/docs/API_TOI_columns.html
#
# ExoFOP documentation: https://exofop.ipac.caltech.edu/tess/tsm.php

# %%
tess_data = replace_label(data=tess_data, mission=Mission.TESS)
print('Shape of TESS data: ', tess_data.shape)
# Out:
# Shape of TESS data:  (6977, 62)

# %% [markdown]
# # Feature and Label Processing
#
# The Kepler and TESS data have different features, so we want to find an intersection between the two sets of data. To do this, we perform several operations:
#
# 1. Removing non-numeric features
# 2. Removing of identifying characteristics
# 3. Identifying the labels (X_train, y_train)
# 4. Removing NaN in y_train and correspondingly also the X_train rows (if there are)

# %%
tess_data, non_numeric_columns = remove_non_numeric_columns(df=tess_data)
print('Non numric columns removed:', non_numeric_columns)
# Out:
# Non numric columns removed: ['Previous CTOI', 'TESS Disposition', 'Source', 'Detection', 'RA', 'Dec', 'Sectors', 'Date TOI Alerted (UTC)', 'Date TOI Updated (UTC)', 'Date Modified', 'Comments']

# %%
col = ['TOI', 'TIC ID', 'Pipeline Signal ID', 'Imaging Observations',
       'Spectroscopy Observations', 'Time Series Observations', 'SG3',
       'SG5', 'SG2', 'SG4', 'Master', 'SG1B', 'SG1A', 'Epoch (BJD)', 'Epoch (BJD) err']
tess_data = tess_data.drop(columns=col, axis=1)

# %%
y_train = tess_data['TFOPWG Disposition']
tess_data = tess_data.drop(columns='TFOPWG Disposition')
X_train = tess_data

# %%
print('Shape of X_test_tess data: ', X_train.shape)
print('Shape of y_test_tess data: ', y_train.shape)
_ = print_count_nan(data=tess_data, name='TESS')
# Out:
# Shape of X_test_tess data:  (6977, 35)
# Shape of y_test_tess data:  (6977,)
# Number of NaN values in TESS: 31406 out of 244195: 12.86%

# %%
_ = print_count_nan(data=y_train, name='y_train')
# Out:
# Number of NaN values in y_train: 98 out of 6977: 1.40%

# %% [markdown]
# In this case there are 98 not a number in the labels so both the y_train and X_train rows are eliminated

# %%
# Removing NaN in y_train and correspondingly also the X_train rows
X_train, y_train = remove_nan_label(X_train, y_train)
count = y_train.isna().sum()
print('Shape of X_train data: ', X_train.shape)
print('Shape of y_train data: ', y_train.shape)
_ = print_count_nan(data=y_train, name='y_train')
# Out:
# Shape of X_train data:  (6879, 35)
# Shape of y_train data:  (6879,)
# Number of NaN values in y_train: 0 out of 6879: 0.00%

# %% [markdown]
# # Data Scaling
#
# Nonostante non costituisca un prerequisito necessario nei modelli di machine learning, il processo di normalizzare i dati è tipicamente impiegato con l'obiettivo di:
#
# 1. Standardizzare l'intervallo di valori di tutte le caratteristiche del dataset
# 2. Migliorare la robustezza numerica degli algoritmi impiegati.
#
# Per fare ciò viene utilizzato un modulo di scikit-learn StandardScaler il quale vuole standardizzare le caratteristiche rimuovendo la media e ridimensionandole alla varianza unitaria. Il punteggio standard di un campione x viene calcolato come:
#
# $$
# z = \frac{x - \mu}{\sigma}
# $$
#
# dove $\mu$ è la media dei campioni di addestramento o zero se with_mean=False, e $\sigma$ è la deviazione standard dei campioni di addestramento o uno se with_std=False.
#
# La standardizzazione induce una variabile aleatoria distribuita secondo una media $\mu$ e varianza $\sigma^2$, ad una variabile aleatoria con distribuzione "standard", ossia di media zero e varianza unitaria.

# %%
print('Plot Before the scaling')
plot_hist_feature_distributions(X_train=X_train)
plot_top_7_difference(X_train=X_train)
# Out:
# Plot Before the scaling

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
X_train_normalized = scaler.fit_transform(X_train)
X_train = pd.DataFrame(X_train_normalized, columns=X_train.columns)
# Out:
# /home/attilio/miniconda3/envs/env_tesi/lib/python3.12/site-packages/sklearn/preprocessing/_data.py:479: RuntimeWarning: All-NaN slice encountered
#   data_min = np.nanmin(X, axis=0)
# /home/attilio/miniconda3/envs/env_tesi/lib/python3.12/site-packages/sklearn/preprocessing/_data.py:480: RuntimeWarning: All-NaN slice encountered
#   data_max = np.nanmax(X, axis=0)

# %% [markdown]
# # K-Nearest Neighbors
#
# The NaN problem must be managed carefully, there are several solutions that can be used, one of these is the KNN methodology which calculates a distance (e.g. Euclidean or Manhattan) between the observations and calculates the new value to be inserted with some methodologies (e.g. IDWM or IRWM) but considering the nearest K, where K is defined a priori, generally for K the square root of N is considered where N is the number of observations, or an approximation is used.
#
# In this case, for efficiency reasons, the sklearn KNNImputer module was used which is optimized.

# %% [markdown]
# Dalla seguente operazione osserviamo che continuano a persistere in NaN in X_train

# %%
_ = print_count_nan(data=X_train, name='X_train')
# Out:
# Number of NaN values in X_train: 30978 out of 240765: 12.87%

# %%
# Calculate columns that contain only nan and the number of nan for each columns
nan_columns = compute_all_columns_nan(data=X_train)
number_of_nan_columns = {col: X_train[col].isna().sum() for col in X_train}
number_of_nan_columns = dict(sorted(number_of_nan_columns.items(), key=lambda x: x[1], reverse=True))
print_nan_numbers_for_features(data=X_train, number_of_nan_columns=number_of_nan_columns)
# Out:
# Columns containing only not a number in X_train: ['Planet Name']
# Number of Observations: 6879
# NaN for each feature
#   1: Planet Name-------------------> 6879
#   2: Stellar Metallicity-----------> 5661
#   3: Stellar Metallicity err-------> 5661
#   4: Stellar log(g) (cm/s^2) err---> 2001
#   5: Stellar Mass (M_Sun) err------> 1874
#   6: Stellar Radius (R_Sun) err----> 1717
#   7: Planet Radius (R_Earth) err---> 1456
#   8: Stellar Mass (M_Sun)----------> 915
#   9: Stellar log(g) (cm/s^2)-------> 789
#  10: Stellar Distance (pc) err-----> 637
#  11: Planet Radius (R_Earth)-------> 467
#  12: Stellar Radius (R_Sun)--------> 467
#  13: Stellar Eff Temp (K) err------> 421
#  14: ESM---------------------------> 383
#  15: TSM---------------------------> 383
#  16: Planet Equil Temp (K)---------> 279
#  17: Stellar Distance (pc)---------> 202
#  18: Planet Insolation (Earth Flux)> 155
#  19: Stellar Eff Temp (K)----------> 130
#  20: PM RA (mas/yr)----------------> 119
#  21: PM RA err (mas/yr)------------> 119
#  22: PM Dec (mas/yr)---------------> 119
#  23: PM Dec err (mas/yr)-----------> 119
#  24: Duration (hours) err----------> 13
#  25: Depth (mmag) err--------------> 6
#  26: Depth (ppm) err---------------> 6
#  27: Predicted Mass (M_Earth)------> 0
#  28: TESS Mag----------------------> 0
#  29: TESS Mag err------------------> 0
#  30: Period (days)-----------------> 0
#  31: Period (days) err-------------> 0
#  32: Duration (hours)--------------> 0
#  33: Depth (mmag)------------------> 0
#  34: Depth (ppm)-------------------> 0
#  35: Planet SNR--------------------> 0
# Total number of not a number in X_train: 30978

# %%
TCOL = 5000
nan_columns = threshold_delete_nan(number_of_nan_columns=number_of_nan_columns,
                                        nan_columns_name=nan_columns, threshold=TCOL)
X_train = X_train.drop(columns=nan_columns)
_ = print_count_nan(data=X_train, name='X_train')
print('Shape:', X_train.shape)
# Out:
# Number of NaN values in X_train: 12777 out of 220128: 5.80%
# Shape: (6879, 32)

# %%
# Compute the number of not a number for each rows
number_of_nan_rows = X_train.isna().sum(axis=1)
TROW = 1
id_rows = rows_id_nan(number_of_nan_rows=number_of_nan_rows,
                      X_train=X_train, threshold=TROW)
# Out:
# Total rows >= of T=1: 2287 out of a total of 6879 By eliminating them you obtain 4592 observations

# %%
# Drop rows >= T
X_train = X_train.drop(id_rows).reset_index(drop=True)
y_train = y_train.drop(id_rows).reset_index(drop=True)
print('Shape of X_train:', X_train.shape)
_ = print_count_nan(data=X_train, name='X_train')
# Out:
# Shape of X_train: (4592, 32)
# Number of NaN values in X_train: 0 out of 146944: 0.00%

# %%
INDEX_OF_K = 10
# Using KNNImputer
X_train = k_nearest_neighbors_imputer(X_train, INDEX_OF_K)
print('Shape of X_train:', X_train.shape)
_ = print_count_nan(data=X_train, name='X_train')
print('Shape of X_train data: ', X_train.shape)
print('Shape of y_train data: ', y_train.shape)
# Out:
# Number of NaN values in X_train: 0 out of 146944: 0.00%
# There are no NaN
# Shape of X_train: (4592, 32)
# Number of NaN values in X_train: 0 out of 146944: 0.00%
# Shape of X_train data:  (4592, 32)
# Shape of y_train data:  (4592,)

# %%
print('Plot After the scaling and KNNImputer')
plot_top_7_difference(X_train=X_train)
plot_hist_feature_distributions(X_train=X_train)
X_train_0, X_train_1 = compute_train_0_1(X_train=X_train, y_train=y_train)
plot_hist_feature_distributions(X_train=X_train_0)
plot_hist_feature_distributions(X_train=X_train_1)
plot_hist_feature_distributions_0_1(X_train_0=X_train_0, X_train_1=X_train_1)
# Out:
# Plot After the scaling and KNNImputer

# %% [markdown]
# # Features Selection
#
# Feature selection is a technique that associates a score with each feature and, based on a threshold T, thresholding is carried out so as to leave only the most important features. This technique is used to reduce overfitting and computational times.
#
# It is done through the use of a Random Forest which provides us with the importance of the features.

# %%
N_JOBS = -1

# %%
feature_importances_ = compute_feature_importance(X_train=X_train, y_train=y_train, n_jobs=N_JOBS)
print_feature_importance(X_train=X_train, feature_importances_=feature_importances_)
# Out:
# 1: TESS Mag----------------------> 0.050872503918003846
# 2: Planet Insolation (Earth Flux)> 0.046886642938119776
# 3: Planet Equil Temp (K)---------> 0.046842244454824045
# 4: Period (days)-----------------> 0.04555712864241288
# 5: Period (days) err-------------> 0.043283443445605516
# 6: Planet Radius (R_Earth)-------> 0.042471991290710505
# 7: Planet Radius (R_Earth) err---> 0.040943688834970425
# 8: Duration (hours)--------------> 0.0377090029876669
# 9: TSM---------------------------> 0.03723500219879915
# 10:ESM---------------------------> 0.03402969073704713
# 11:Stellar Radius (R_Sun)--------> 0.031011202759309225
# 12:Stellar Distance (pc)---------> 0.029787263446096758
# 13:Stellar Radius (R_Sun) err----> 0.029418823318195682
# 14:Depth (ppm)-------------------> 0.02845571851171828
# 15:Depth (mmag)------------------> 0.028410144419707347
# 16:Stellar Distance (pc) err-----> 0.027965381908077912
# 17:Stellar Eff Temp (K) err------> 0.02792382552376927
# 18:Duration (hours) err----------> 0.027784785991163272
# 19:Planet SNR--------------------> 0.0270491763381265
# 20:Depth (mmag) err--------------> 0.02698449337368007
# 21:PM Dec (mas/yr)---------------> 0.026640084540734753
# 22:PM RA (mas/yr)----------------> 0.026604634218030734
# 23:Depth (ppm) err---------------> 0.026468011207181265
# 24:Stellar Mass (M_Sun) err------> 0.02629354205310957
# 25:Stellar Mass (M_Sun)----------> 0.02589573003942753
# 26:Stellar log(g) (cm/s^2)-------> 0.025852624836953074
# 27:Stellar Eff Temp (K)----------> 0.024910051539759653
# 28:PM Dec err (mas/yr)-----------> 0.02477814272170512
# 29:Predicted Mass (M_Earth)------> 0.024232774391971353
# 30:PM RA err (mas/yr)------------> 0.024167628410938474
# 31:Stellar log(g) (cm/s^2) err---> 0.02378940625350137
# 32:TESS Mag err------------------> 0.009745214748682564

# %%
plot_feature_importances(X_train=X_train, feature_importances=feature_importances_)

# %%
PERCENTAGE = None # Drop features with importance = 0 + min
X_train, columns_to_drop = feature_selection_rfc(X_train=X_train, feature_importances=feature_importances_,
                                                 percentage=PERCENTAGE)
print('Columns to drop:', columns_to_drop)
print('Shape of X_train data: ', X_train.shape)
# Out:
# Threshold computed:  0
# Columns to drop: Index([], dtype='object')
# Shape of X_train data:  (6554, 32)

# %% [markdown]
# # Data balancing

# %%
class_count_1, class_count_0 = plot_class_distribution(y_train)

# %%
print('Observations labeled 1:', class_count_1)
print('Observations labeled 0:', class_count_0)
# Out:
# Observations labeled 1: 3629.0
# Observations labeled 0: 963.0

# %%
# Save processed data
X_train.to_csv('../data/processed_data/X_tess_mms.csv')
y_train.to_csv('../data/processed_data/y_tess_mms.csv')

# %% [markdown]
# # Oversampling
#
# Adds more sample instances to balance the dataset.
# SMOTE randomly selects an element from the minority class and identifies its nearest neighbors: the new instance is created between them. https://www.sciencedirect.com/science/article/pii/S0164121220301448

# %%
RANDOM_STATE = 42
# X_train, y_train = smote_oversampling(X_train=X_train, y_train=y_train, random_state=RANDOM_STATE)

# %% [markdown]
# # Class weighting
#
# The error of the minority class weighs differently

# %%
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

# Calculate class weights
class_weights = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)

# Create class weight dictionary
class_weight_dict = dict(zip(np.unique(y_train), class_weights))

# %%
_, _ = plot_class_distribution(y_train)

# %% [markdown]
# # Train Test Split

# %%
TESTSET_SIZE = 0.2
RANDOM_STATE = 42

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=TESTSET_SIZE, 
                                                    random_state=RANDOM_STATE, shuffle=True, stratify=None)

# %% [markdown]
# # Checking class distributions after the split

# %%
_, _ = plot_class_distribution(y_train)

# %%
_, _ = plot_class_distribution(y_test)

# %%
print('Shape of X_train data: ', X_train.shape)
print('Shape of y_train data: ', y_train.shape)
print('Shape of X_test data: ', X_test.shape)
print('Shape of y_test data: ', y_test.shape)
# Out:
# Shape of X_train data:  (5243, 32)
# Shape of y_train data:  (5243,)
# Shape of X_test data:  (1311, 32)
# Shape of y_test data:  (1311,)

# %% [markdown]
# # Grid Searh
#
# A common method that determines optimal parameters by evaluating metrics
# of the model

# %%
best_params, best_score, best_estimator = grid_search_param_optimization(X_train=X_train,
                                                                         y_train=y_train, n_jobs=N_JOBS)
print('Best params:', best_params)
print('Best score:', best_score)
print('Best estimator:', best_estimator)
# Out:
# Fitting 5 folds for each of 360 candidates, totalling 1800 fits
# [CV] END max_depth=2, max_features=2, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END max_depth=2, max_features=2, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END max_depth=2, max_features=2, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END max_depth=2, max_features=2, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END max_depth=2, max_features=2, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END max_depth=2, max_features=2, min_samples_split=3, n_estimators=100; total time=   0.5s
# [CV] END max_depth=2, max_features=2, min_samples_split=3, n_estimators=100; total time=   0.5s
# [CV] END max_depth=2, max_features=2, min_samples_split=3, n_estimators=100; total time=   0.5s
# [CV] END max_depth=2, max_features=2, min_samples_split=3, n_estimators=100; total time=   0.6s
# [CV] END max_depth=2, max_features=2, min_samples_split=3, n_estimators=100; total time=   0.7s
# [CV] END max_depth=2, max_features=2, min_samples_split=2, n_estimators=300; total time=   0.9s
# [CV] END max_depth=2, max_features=2, min_samples_split=2, n_estimators=300; total time=   1.1s
# [CV] END max_depth=2, max_features=2, min_samples_split=2, n_estimators=300; total time=   1.0s
# [CV] END max_depth=2, max_features=2, min_samples_split=2, n_estimators=300; total time=   1.1s
# [CV] END max_depth=2, max_features=2, min_samples_split=2, n_estimators=300; total time=   1.2s
# [CV] END max_depth=2, max_features=2, min_samples_split=2, n_estimators=500; total time=   1.4s
# [CV] END max_depth=2, max_features=2, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=2, max_features=2, min_samples_split=3, n_estimators=300; total time=   1.1s
# [CV] END max_depth=2, max_features=2, min_samples_split=2, n_estimators=500; total time=   1.6s
# [CV] END max_depth=2, max_features=2, min_samples_split=2, n_estimators=500; total time=   1.6s
# [CV] END max_depth=2, max_features=2, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END max_depth=2, max_features=2, min_samples_split=2, n_estimators=500; total time=   1.6s
# [CV] END max_depth=2, max_features=2, min_samples_split=3, n_estimators=300; total time=   1.2s
# [CV] END max_depth=2, max_features=2, min_samples_split=2, n_estimators=500; total time=   1.6s
# [CV] END max_depth=2, max_features=2, min_samples_split=3, n_estimators=300; total time=   1.2s
# [CV] END max_depth=2, max_features=2, min_samples_split=3, n_estimators=300; total time=   1.3s
# [CV] END max_depth=2, max_features=2, min_samples_split=3, n_estimators=300; total time=   1.2s
# [CV] END max_depth=2, max_features=2, min_samples_split=5, n_estimators=100; total time=   0.6s
# [CV] END max_depth=2, max_features=2, min_samples_split=5, n_estimators=100; total time=   0.6s
# [CV] END max_depth=2, max_features=2, min_samples_split=5, n_estimators=100; total time=   0.6s
# [CV] END max_depth=2, max_features=2, min_samples_split=3, n_estimators=500; total time=   1.4s
# [CV] END max_depth=2, max_features=2, min_samples_split=6, n_estimators=100; total time=   0.5s
# [CV] END max_depth=2, max_features=2, min_samples_split=6, n_estimators=100; total time=   0.7s
# [CV] END max_depth=2, max_features=2, min_samples_split=3, n_estimators=500; total time=   1.8s
# [CV] END max_depth=2, max_features=2, min_samples_split=6, n_estimators=100; total time=   0.6s
# [CV] END max_depth=2, max_features=2, min_samples_split=5, n_estimators=300; total time=   1.0s
# [CV] END max_depth=2, max_features=2, min_samples_split=3, n_estimators=500; total time=   1.8s
# [CV] END max_depth=2, max_features=2, min_samples_split=6, n_estimators=100; total time=   0.6s
# [CV] END max_depth=2, max_features=2, min_samples_split=5, n_estimators=300; total time=   1.1s
# [CV] END max_depth=2, max_features=2, min_samples_split=3, n_estimators=500; total time=   1.7s
# [CV] END max_depth=2, max_features=2, min_samples_split=3, n_estimators=500; total time=   1.9s
# [CV] END max_depth=2, max_features=2, min_samples_split=5, n_estimators=300; total time=   1.1s
# [CV] END max_depth=2, max_features=2, min_samples_split=5, n_estimators=300; total time=   1.1s
# [CV] END max_depth=2, max_features=2, min_samples_split=5, n_estimators=300; total time=   1.1s
# [CV] END max_depth=2, max_features=2, min_samples_split=6, n_estimators=100; total time=   0.9s
# [CV] END max_depth=2, max_features=2, min_samples_split=7, n_estimators=100; total time=   0.5s
# [CV] END max_depth=2, max_features=2, min_samples_split=5, n_estimators=500; total time=   1.6s
# [CV] END max_depth=2, max_features=2, min_samples_split=7, n_estimators=100; total time=   0.6s
# [CV] END max_depth=2, max_features=2, min_samples_split=6, n_estimators=300; total time=   1.1s
# [CV] END max_depth=2, max_features=2, min_samples_split=7, n_estimators=100; total time=   0.6s
# [CV] END max_depth=2, max_features=2, min_samples_split=7, n_estimators=100; total time=   0.7s
# [CV] END max_depth=2, max_features=2, min_samples_split=5, n_estimators=500; total time=   1.7s
# [CV] END max_depth=2, max_features=2, min_samples_split=5, n_estimators=500; total time=   1.7s
# [CV] END max_depth=2, max_features=2, min_samples_split=5, n_estimators=500; total time=   1.7s
# [CV] END max_depth=2, max_features=2, min_samples_split=7, n_estimators=100; total time=   0.7s
# [CV] END max_depth=2, max_features=2, min_samples_split=6, n_estimators=300; total time=   1.4s
# [CV] END max_depth=2, max_features=2, min_samples_split=5, n_estimators=500; total time=   1.9s
# [CV] END max_depth=2, max_features=2, min_samples_split=6, n_estimators=300; total time=   1.1s
# [CV] END max_depth=2, max_features=2, min_samples_split=6, n_estimators=300; total time=   1.1s
# [CV] END max_depth=2, max_features=2, min_samples_split=6, n_estimators=300; total time=   1.1s
# [CV] END max_depth=2, max_features=2, min_samples_split=9, n_estimators=100; total time=   0.5s
# [CV] END max_depth=2, max_features=2, min_samples_split=9, n_estimators=100; total time=   0.6s
# [CV] END max_depth=2, max_features=2, min_samples_split=9, n_estimators=100; total time=   0.6s
# [CV] END max_depth=2, max_features=2, min_samples_split=9, n_estimators=100; total time=   0.6s
# [CV] END max_depth=2, max_features=2, min_samples_split=9, n_estimators=100; total time=   0.7s
# [CV] END max_depth=2, max_features=2, min_samples_split=6, n_estimators=500; total time=   1.7s
# [CV] END max_depth=2, max_features=2, min_samples_split=6, n_estimators=500; total time=   1.7s[CV] END max_depth=2, max_features=2, min_samples_split=7, n_estimators=300; total time=   1.0s
#
# [CV] END max_depth=2, max_features=2, min_samples_split=7, n_estimators=300; total time=   1.1s
# [CV] END max_depth=2, max_features=2, min_samples_split=6, n_estimators=500; total time=   1.7s
# [CV] END max_depth=2, max_features=2, min_samples_split=7, n_estimators=300; total time=   1.1s
# [CV] END max_depth=2, max_features=2, min_samples_split=6, n_estimators=500; total time=   1.8s
# [CV] END max_depth=2, max_features=2, min_samples_split=6, n_estimators=500; total time=   1.8s
# [CV] END max_depth=2, max_features=2, min_samples_split=7, n_estimators=300; total time=   1.1s
# [CV] END max_depth=2, max_features=2, min_samples_split=7, n_estimators=300; total time=   1.2s
# [CV] END max_depth=2, max_features=3, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END max_depth=2, max_features=3, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END max_depth=2, max_features=3, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END max_depth=2, max_features=2, min_samples_split=7, n_estimators=500; total time=   1.6s
# [CV] END max_depth=2, max_features=2, min_samples_split=7, n_estimators=500; total time=   1.7s
# [CV] END max_depth=2, max_features=3, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END max_depth=2, max_features=2, min_samples_split=9, n_estimators=300; total time=   1.1s
# [CV] END max_depth=2, max_features=2, min_samples_split=9, n_estimators=300; total time=   1.0s
# [CV] END max_depth=2, max_features=2, min_samples_split=7, n_estimators=500; total time=   1.8s
# [CV] END max_depth=2, max_features=2, min_samples_split=7, n_estimators=500; total time=   1.8s
# [CV] END max_depth=2, max_features=2, min_samples_split=7, n_estimators=500; total time=   1.8s
# [CV] END max_depth=2, max_features=3, min_samples_split=2, n_estimators=100; total time=   0.7s
# [CV] END max_depth=2, max_features=2, min_samples_split=9, n_estimators=300; total time=   1.1s
# [CV] END max_depth=2, max_features=2, min_samples_split=9, n_estimators=300; total time=   1.1s
# [CV] END max_depth=2, max_features=2, min_samples_split=9, n_estimators=300; total time=   1.2s
# [CV] END max_depth=2, max_features=3, min_samples_split=3, n_estimators=100; total time=   0.7s
# [CV] END max_depth=2, max_features=3, min_samples_split=3, n_estimators=100; total time=   0.8s
# [CV] END max_depth=2, max_features=2, min_samples_split=9, n_estimators=500; total time=   1.7s
# [CV] END max_depth=2, max_features=3, min_samples_split=3, n_estimators=100; total time=   0.7s
# [CV] END max_depth=2, max_features=2, min_samples_split=9, n_estimators=500; total time=   1.7s
# [CV] END max_depth=2, max_features=3, min_samples_split=3, n_estimators=100; total time=   0.7s
# [CV] END max_depth=2, max_features=3, min_samples_split=3, n_estimators=100; total time=   0.7s
# [CV] END max_depth=2, max_features=2, min_samples_split=9, n_estimators=500; total time=   1.8s
# [CV] END max_depth=2, max_features=3, min_samples_split=2, n_estimators=300; total time=   1.3s
# [CV] END max_depth=2, max_features=3, min_samples_split=2, n_estimators=300; total time=   1.2s
# [CV] END max_depth=2, max_features=3, min_samples_split=2, n_estimators=300; total time=   1.4s
# [CV] END max_depth=2, max_features=2, min_samples_split=9, n_estimators=500; total time=   2.0s
# [CV] END max_depth=2, max_features=2, min_samples_split=9, n_estimators=500; total time=   2.0s
# [CV] END max_depth=2, max_features=3, min_samples_split=2, n_estimators=300; total time=   1.3s
# [CV] END max_depth=2, max_features=3, min_samples_split=2, n_estimators=300; total time=   1.5s
# [CV] END max_depth=2, max_features=3, min_samples_split=5, n_estimators=100; total time=   0.6s
# [CV] END max_depth=2, max_features=3, min_samples_split=2, n_estimators=500; total time=   1.8s
# [CV] END max_depth=2, max_features=3, min_samples_split=5, n_estimators=100; total time=   0.6s
# [CV] END max_depth=2, max_features=3, min_samples_split=2, n_estimators=500; total time=   1.9s
# [CV] END max_depth=2, max_features=3, min_samples_split=5, n_estimators=100; total time=   0.7s
# [CV] END max_depth=2, max_features=3, min_samples_split=3, n_estimators=300; total time=   1.1s
# [CV] END max_depth=2, max_features=3, min_samples_split=5, n_estimators=100; total time=   0.9s
# [CV] END max_depth=2, max_features=3, min_samples_split=3, n_estimators=300; total time=   1.2s
# [CV] END max_depth=2, max_features=3, min_samples_split=3, n_estimators=300; total time=   1.1s
# [CV] END max_depth=2, max_features=3, min_samples_split=3, n_estimators=300; total time=   1.2s
# [CV] END max_depth=2, max_features=3, min_samples_split=5, n_estimators=100; total time=   0.9s
# [CV] END max_depth=2, max_features=3, min_samples_split=2, n_estimators=500; total time=   2.1s
# [CV] END max_depth=2, max_features=3, min_samples_split=3, n_estimators=300; total time=   1.2s
# [CV] END max_depth=2, max_features=3, min_samples_split=2, n_estimators=500; total time=   2.0s
# [CV] END max_depth=2, max_features=3, min_samples_split=2, n_estimators=500; total time=   2.1s
# [CV] END max_depth=2, max_features=3, min_samples_split=6, n_estimators=100; total time=   0.5s
# [CV] END max_depth=2, max_features=3, min_samples_split=6, n_estimators=100; total time=   0.7s
# [CV] END max_depth=2, max_features=3, min_samples_split=3, n_estimators=500; total time=   1.9s
# [CV] END max_depth=2, max_features=3, min_samples_split=6, n_estimators=100; total time=   0.8s
# [CV] END max_depth=2, max_features=3, min_samples_split=6, n_estimators=100; total time=   0.8s
# [CV] END max_depth=2, max_features=3, min_samples_split=6, n_estimators=100; total time=   0.8s
# [CV] END max_depth=2, max_features=3, min_samples_split=5, n_estimators=300; total time=   1.1s
# [CV] END max_depth=2, max_features=3, min_samples_split=5, n_estimators=300; total time=   1.2s
# [CV] END max_depth=2, max_features=3, min_samples_split=3, n_estimators=500; total time=   2.0s
# [CV] END max_depth=2, max_features=3, min_samples_split=3, n_estimators=500; total time=   2.0s
# [CV] END max_depth=2, max_features=3, min_samples_split=5, n_estimators=300; total time=   1.1s
# [CV] END max_depth=2, max_features=3, min_samples_split=5, n_estimators=300; total time=   1.3s
# [CV] END max_depth=2, max_features=3, min_samples_split=3, n_estimators=500; total time=   2.1s
# [CV] END max_depth=2, max_features=3, min_samples_split=3, n_estimators=500; total time=   2.1s
# [CV] END max_depth=2, max_features=3, min_samples_split=5, n_estimators=300; total time=   1.2s
# [CV] END max_depth=2, max_features=3, min_samples_split=7, n_estimators=100; total time=   0.5s
# [CV] END max_depth=2, max_features=3, min_samples_split=7, n_estimators=100; total time=   0.7s
# [CV] END max_depth=2, max_features=3, min_samples_split=5, n_estimators=500; total time=   1.9s
# [CV] END max_depth=2, max_features=3, min_samples_split=5, n_estimators=500; total time=   1.8s
# [CV] END max_depth=2, max_features=3, min_samples_split=7, n_estimators=100; total time=   0.7s
# [CV] END max_depth=2, max_features=3, min_samples_split=7, n_estimators=100; total time=   0.8s
# [CV] END max_depth=2, max_features=3, min_samples_split=6, n_estimators=300; total time=   1.4s
# [CV] END max_depth=2, max_features=3, min_samples_split=6, n_estimators=300; total time=   1.1s
# [CV] END max_depth=2, max_features=3, min_samples_split=6, n_estimators=300; total time=   1.2s
# [CV] END max_depth=2, max_features=3, min_samples_split=5, n_estimators=500; total time=   2.1s
# [CV] END max_depth=2, max_features=3, min_samples_split=7, n_estimators=100; total time=   0.9s
# [CV] END max_depth=2, max_features=3, min_samples_split=5, n_estimators=500; total time=   2.1s
# [CV] END max_depth=2, max_features=3, min_samples_split=6, n_estimators=300; total time=   1.3s
# [CV] END max_depth=2, max_features=3, min_samples_split=5, n_estimators=500; total time=   2.2s
# [CV] END max_depth=2, max_features=3, min_samples_split=6, n_estimators=300; total time=   1.4s
# [CV] END max_depth=2, max_features=3, min_samples_split=7, n_estimators=300; total time=   1.2s
# [CV] END max_depth=2, max_features=3, min_samples_split=9, n_estimators=100; total time=   0.6s
# [CV] END max_depth=2, max_features=3, min_samples_split=9, n_estimators=100; total time=   0.6s
# [CV] END max_depth=2, max_features=3, min_samples_split=6, n_estimators=500; total time=   2.0s
# [CV] END max_depth=2, max_features=3, min_samples_split=9, n_estimators=100; total time=   0.7s
# [CV] END max_depth=2, max_features=3, min_samples_split=9, n_estimators=100; total time=   0.8s
# [CV] END max_depth=2, max_features=3, min_samples_split=9, n_estimators=100; total time=   0.8s
# [CV] END max_depth=2, max_features=3, min_samples_split=6, n_estimators=500; total time=   2.1s
# [CV] END max_depth=2, max_features=3, min_samples_split=6, n_estimators=500; total time=   2.1s
# [CV] END max_depth=2, max_features=3, min_samples_split=6, n_estimators=500; total time=   2.1s
# [CV] END max_depth=2, max_features=3, min_samples_split=7, n_estimators=300; total time=   1.2s
# [CV] END max_depth=2, max_features=3, min_samples_split=7, n_estimators=300; total time=   1.3s
# [CV] END max_depth=2, max_features=3, min_samples_split=7, n_estimators=300; total time=   1.2s
# [CV] END max_depth=2, max_features=3, min_samples_split=6, n_estimators=500; total time=   2.2s
# [CV] END max_depth=2, max_features=3, min_samples_split=7, n_estimators=300; total time=   1.3s
# [CV] END max_depth=2, max_features=4, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END max_depth=2, max_features=4, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END max_depth=2, max_features=4, min_samples_split=2, n_estimators=100; total time=   0.7s
# [CV] END max_depth=2, max_features=4, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END max_depth=2, max_features=3, min_samples_split=9, n_estimators=300; total time=   1.1s
# [CV] END max_depth=2, max_features=3, min_samples_split=7, n_estimators=500; total time=   2.0s
# [CV] END max_depth=2, max_features=3, min_samples_split=7, n_estimators=500; total time=   1.8s
# [CV] END max_depth=2, max_features=3, min_samples_split=9, n_estimators=300; total time=   1.1s
# [CV] END max_depth=2, max_features=3, min_samples_split=7, n_estimators=500; total time=   2.0s
# [CV] END max_depth=2, max_features=3, min_samples_split=9, n_estimators=300; total time=   1.2s
# [CV] END max_depth=2, max_features=4, min_samples_split=2, n_estimators=100; total time=   0.9s
# [CV] END max_depth=2, max_features=3, min_samples_split=7, n_estimators=500; total time=   2.0s
# [CV] END max_depth=2, max_features=3, min_samples_split=9, n_estimators=300; total time=   1.2s
# [CV] END max_depth=2, max_features=3, min_samples_split=9, n_estimators=300; total time=   1.2s
# [CV] END max_depth=2, max_features=3, min_samples_split=7, n_estimators=500; total time=   2.2s
# [CV] END max_depth=2, max_features=4, min_samples_split=3, n_estimators=100; total time=   0.5s
# [CV] END max_depth=2, max_features=3, min_samples_split=9, n_estimators=500; total time=   1.7s
# [CV] END max_depth=2, max_features=4, min_samples_split=3, n_estimators=100; total time=   0.6s
# [CV] END max_depth=2, max_features=4, min_samples_split=3, n_estimators=100; total time=   0.7s
# [CV] END max_depth=2, max_features=4, min_samples_split=3, n_estimators=100; total time=   0.7s
# [CV] END max_depth=2, max_features=4, min_samples_split=2, n_estimators=300; total time=   1.2s
# [CV] END max_depth=2, max_features=3, min_samples_split=9, n_estimators=500; total time=   2.0s
# [CV] END max_depth=2, max_features=3, min_samples_split=9, n_estimators=500; total time=   2.1s
# [CV] END max_depth=2, max_features=4, min_samples_split=3, n_estimators=100; total time=   0.8s
# [CV] END max_depth=2, max_features=4, min_samples_split=2, n_estimators=300; total time=   1.3s
# [CV] END max_depth=2, max_features=4, min_samples_split=2, n_estimators=300; total time=   1.5s
# [CV] END max_depth=2, max_features=4, min_samples_split=2, n_estimators=300; total time=   1.6s
# [CV] END max_depth=2, max_features=3, min_samples_split=9, n_estimators=500; total time=   2.4s
# [CV] END max_depth=2, max_features=3, min_samples_split=9, n_estimators=500; total time=   2.4s
# [CV] END max_depth=2, max_features=4, min_samples_split=5, n_estimators=100; total time=   0.6s
# [CV] END max_depth=2, max_features=4, min_samples_split=2, n_estimators=300; total time=   1.9s
# [CV] END max_depth=2, max_features=4, min_samples_split=3, n_estimators=300; total time=   1.4s
# [CV] END max_depth=2, max_features=4, min_samples_split=3, n_estimators=300; total time=   1.5s
# [CV] END max_depth=2, max_features=4, min_samples_split=3, n_estimators=300; total time=   1.3s
# [CV] END max_depth=2, max_features=4, min_samples_split=5, n_estimators=100; total time=   0.6s
# [CV] END max_depth=2, max_features=4, min_samples_split=2, n_estimators=500; total time=   2.2s
# [CV] END max_depth=2, max_features=4, min_samples_split=5, n_estimators=100; total time=   0.7s
# [CV] END max_depth=2, max_features=4, min_samples_split=3, n_estimators=300; total time=   1.6s
# [CV] END max_depth=2, max_features=4, min_samples_split=3, n_estimators=300; total time=   1.5s
# [CV] END max_depth=2, max_features=4, min_samples_split=5, n_estimators=100; total time=   0.8s
# [CV] END max_depth=2, max_features=4, min_samples_split=2, n_estimators=500; total time=   2.5s
# [CV] END max_depth=2, max_features=4, min_samples_split=2, n_estimators=500; total time=   2.5s
# [CV] END max_depth=2, max_features=4, min_samples_split=2, n_estimators=500; total time=   2.6s
# [CV] END max_depth=2, max_features=4, min_samples_split=5, n_estimators=100; total time=   0.8s
# [CV] END max_depth=2, max_features=4, min_samples_split=2, n_estimators=500; total time=   2.9s
# [CV] END max_depth=2, max_features=4, min_samples_split=3, n_estimators=500; total time=   2.1s
# [CV] END max_depth=2, max_features=4, min_samples_split=5, n_estimators=300; total time=   1.5s
# [CV] END max_depth=2, max_features=4, min_samples_split=3, n_estimators=500; total time=   2.5s
# [CV] END max_depth=2, max_features=4, min_samples_split=6, n_estimators=100; total time=   1.0s
# [CV] END max_depth=2, max_features=4, min_samples_split=5, n_estimators=300; total time=   1.4s
# [CV] END max_depth=2, max_features=4, min_samples_split=6, n_estimators=100; total time=   0.9s
# [CV] END max_depth=2, max_features=4, min_samples_split=6, n_estimators=100; total time=   0.9s
# [CV] END max_depth=2, max_features=4, min_samples_split=6, n_estimators=100; total time=   1.0s
# [CV] END max_depth=2, max_features=4, min_samples_split=3, n_estimators=500; total time=   2.5s
# [CV] END max_depth=2, max_features=4, min_samples_split=5, n_estimators=300; total time=   1.4s
# [CV] END max_depth=2, max_features=4, min_samples_split=3, n_estimators=500; total time=   2.4s
# [CV] END max_depth=2, max_features=4, min_samples_split=5, n_estimators=300; total time=   1.5s
# [CV] END max_depth=2, max_features=4, min_samples_split=6, n_estimators=100; total time=   0.8s
# [CV] END max_depth=2, max_features=4, min_samples_split=3, n_estimators=500; total time=   2.6s
# [CV] END max_depth=2, max_features=4, min_samples_split=5, n_estimators=300; total time=   1.7s
# [CV] END max_depth=2, max_features=4, min_samples_split=7, n_estimators=100; total time=   0.6s
# [CV] END max_depth=2, max_features=4, min_samples_split=5, n_estimators=500; total time=   2.2s
# [CV] END max_depth=2, max_features=4, min_samples_split=7, n_estimators=100; total time=   0.9s
# [CV] END max_depth=2, max_features=4, min_samples_split=5, n_estimators=500; total time=   2.3s
# [CV] END max_depth=2, max_features=4, min_samples_split=5, n_estimators=500; total time=   2.4s
# [CV] END max_depth=2, max_features=4, min_samples_split=5, n_estimators=500; total time=   2.3s
# [CV] END max_depth=2, max_features=4, min_samples_split=7, n_estimators=100; total time=   0.8s
# [CV] END max_depth=2, max_features=4, min_samples_split=7, n_estimators=100; total time=   0.9s
# [CV] END max_depth=2, max_features=4, min_samples_split=6, n_estimators=300; total time=   1.3s
# [CV] END max_depth=2, max_features=4, min_samples_split=7, n_estimators=100; total time=   1.0s
# [CV] END max_depth=2, max_features=4, min_samples_split=6, n_estimators=300; total time=   1.4s
# [CV] END max_depth=2, max_features=4, min_samples_split=6, n_estimators=300; total time=   1.3s
# [CV] END max_depth=2, max_features=4, min_samples_split=5, n_estimators=500; total time=   2.5s
# [CV] END max_depth=2, max_features=4, min_samples_split=6, n_estimators=300; total time=   1.5s
# [CV] END max_depth=2, max_features=4, min_samples_split=6, n_estimators=300; total time=   1.9s
# [CV] END max_depth=2, max_features=4, min_samples_split=6, n_estimators=500; total time=   1.9s
# [CV] END max_depth=2, max_features=4, min_samples_split=9, n_estimators=100; total time=   0.7s
# [CV] END max_depth=2, max_features=4, min_samples_split=9, n_estimators=100; total time=   0.7s
# [CV] END max_depth=2, max_features=4, min_samples_split=7, n_estimators=300; total time=   1.5s
# [CV] END max_depth=2, max_features=4, min_samples_split=9, n_estimators=100; total time=   0.7s
# [CV] END max_depth=2, max_features=4, min_samples_split=9, n_estimators=100; total time=   0.9s
# [CV] END max_depth=2, max_features=4, min_samples_split=6, n_estimators=500; total time=   2.1s
# [CV] END max_depth=2, max_features=4, min_samples_split=6, n_estimators=500; total time=   2.1s
# [CV] END max_depth=2, max_features=4, min_samples_split=6, n_estimators=500; total time=   2.1s
# [CV] END max_depth=2, max_features=4, min_samples_split=7, n_estimators=300; total time=   1.4s
# [CV] END max_depth=2, max_features=4, min_samples_split=7, n_estimators=300; total time=   1.3s
# [CV] END max_depth=2, max_features=4, min_samples_split=7, n_estimators=300; total time=   1.3s
# [CV] END max_depth=2, max_features=4, min_samples_split=7, n_estimators=300; total time=   1.5s
# [CV] END max_depth=2, max_features=4, min_samples_split=6, n_estimators=500; total time=   2.4s
# [CV] END max_depth=2, max_features=4, min_samples_split=9, n_estimators=100; total time=   0.8s
# [CV] END max_depth=2, max_features=5, min_samples_split=2, n_estimators=100; total time=   0.7s
# [CV] END max_depth=2, max_features=5, min_samples_split=2, n_estimators=100; total time=   0.9s
# [CV] END max_depth=2, max_features=5, min_samples_split=2, n_estimators=100; total time=   0.8s
# [CV] END max_depth=2, max_features=4, min_samples_split=7, n_estimators=500; total time=   2.1s
# [CV] END max_depth=2, max_features=4, min_samples_split=7, n_estimators=500; total time=   2.2s
# [CV] END max_depth=2, max_features=5, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END max_depth=2, max_features=4, min_samples_split=9, n_estimators=300; total time=   1.2s
# [CV] END max_depth=2, max_features=4, min_samples_split=7, n_estimators=500; total time=   2.3s
# [CV] END max_depth=2, max_features=4, min_samples_split=7, n_estimators=500; total time=   2.1s
# [CV] END max_depth=2, max_features=4, min_samples_split=9, n_estimators=300; total time=   1.3s
# [CV] END max_depth=2, max_features=4, min_samples_split=9, n_estimators=300; total time=   1.4s
# [CV] END max_depth=2, max_features=5, min_samples_split=2, n_estimators=100; total time=   0.8s
# [CV] END max_depth=2, max_features=4, min_samples_split=9, n_estimators=300; total time=   1.5s
# [CV] END max_depth=2, max_features=4, min_samples_split=9, n_estimators=300; total time=   1.7s
# [CV] END max_depth=2, max_features=4, min_samples_split=7, n_estimators=500; total time=   2.6s
# [CV] END max_depth=2, max_features=5, min_samples_split=3, n_estimators=100; total time=   0.6s
# [CV] END max_depth=2, max_features=5, min_samples_split=3, n_estimators=100; total time=   0.9s
# [CV] END max_depth=2, max_features=5, min_samples_split=3, n_estimators=100; total time=   1.0s
# [CV] END max_depth=2, max_features=4, min_samples_split=9, n_estimators=500; total time=   2.5s
# [CV] END max_depth=2, max_features=5, min_samples_split=3, n_estimators=100; total time=   0.9s
# [CV] END max_depth=2, max_features=5, min_samples_split=2, n_estimators=300; total time=   1.4s
# [CV] END max_depth=2, max_features=4, min_samples_split=9, n_estimators=500; total time=   2.5s
# [CV] END max_depth=2, max_features=4, min_samples_split=9, n_estimators=500; total time=   2.6s
# [CV] END max_depth=2, max_features=5, min_samples_split=3, n_estimators=100; total time=   1.1s
# [CV] END max_depth=2, max_features=5, min_samples_split=2, n_estimators=300; total time=   1.6s
# [CV] END max_depth=2, max_features=4, min_samples_split=9, n_estimators=500; total time=   2.6s
# [CV] END max_depth=2, max_features=5, min_samples_split=2, n_estimators=300; total time=   1.6s
# [CV] END max_depth=2, max_features=5, min_samples_split=2, n_estimators=300; total time=   1.6s
# [CV] END max_depth=2, max_features=4, min_samples_split=9, n_estimators=500; total time=   2.5s
# [CV] END max_depth=2, max_features=5, min_samples_split=2, n_estimators=300; total time=   1.6s
# [CV] END max_depth=2, max_features=5, min_samples_split=5, n_estimators=100; total time=   0.8s
# [CV] END max_depth=2, max_features=5, min_samples_split=2, n_estimators=500; total time=   2.4s
# [CV] END max_depth=2, max_features=5, min_samples_split=2, n_estimators=500; total time=   2.4s
# [CV] END max_depth=2, max_features=5, min_samples_split=5, n_estimators=100; total time=   0.9s
# [CV] END max_depth=2, max_features=5, min_samples_split=2, n_estimators=500; total time=   2.4s
# [CV] END max_depth=2, max_features=5, min_samples_split=3, n_estimators=300; total time=   1.4s
# [CV] END max_depth=2, max_features=5, min_samples_split=5, n_estimators=100; total time=   1.0s
# [CV] END max_depth=2, max_features=5, min_samples_split=2, n_estimators=500; total time=   2.5s
# [CV] END max_depth=2, max_features=5, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END max_depth=2, max_features=5, min_samples_split=3, n_estimators=300; total time=   1.3s
# [CV] END max_depth=2, max_features=5, min_samples_split=3, n_estimators=300; total time=   1.5s
# [CV] END max_depth=2, max_features=5, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END max_depth=2, max_features=5, min_samples_split=3, n_estimators=300; total time=   1.9s
# [CV] END max_depth=2, max_features=5, min_samples_split=2, n_estimators=500; total time=   2.6s
# [CV] END max_depth=2, max_features=5, min_samples_split=3, n_estimators=300; total time=   1.4s
# [CV] END max_depth=2, max_features=5, min_samples_split=6, n_estimators=100; total time=   0.8s
# [CV] END max_depth=2, max_features=5, min_samples_split=6, n_estimators=100; total time=   0.9s
# [CV] END max_depth=2, max_features=5, min_samples_split=6, n_estimators=100; total time=   1.0s
# [CV] END max_depth=2, max_features=5, min_samples_split=6, n_estimators=100; total time=   1.0s
# [CV] END max_depth=2, max_features=5, min_samples_split=3, n_estimators=500; total time=   2.6s
# [CV] END max_depth=2, max_features=5, min_samples_split=6, n_estimators=100; total time=   1.2s
# [CV] END max_depth=2, max_features=5, min_samples_split=3, n_estimators=500; total time=   2.6s
# [CV] END max_depth=2, max_features=5, min_samples_split=5, n_estimators=300; total time=   1.6s
# [CV] END max_depth=2, max_features=5, min_samples_split=5, n_estimators=300; total time=   1.6s
# [CV] END max_depth=2, max_features=5, min_samples_split=3, n_estimators=500; total time=   2.7s
# [CV] END max_depth=2, max_features=5, min_samples_split=5, n_estimators=300; total time=   1.7s
# [CV] END max_depth=2, max_features=5, min_samples_split=5, n_estimators=300; total time=   1.8s
# [CV] END max_depth=2, max_features=5, min_samples_split=3, n_estimators=500; total time=   2.8s
# [CV] END max_depth=2, max_features=5, min_samples_split=5, n_estimators=300; total time=   2.0s
# [CV] END max_depth=2, max_features=5, min_samples_split=3, n_estimators=500; total time=   3.1s
# [CV] END max_depth=2, max_features=5, min_samples_split=5, n_estimators=500; total time=   2.2s
# [CV] END max_depth=2, max_features=5, min_samples_split=6, n_estimators=300; total time=   1.3s
# [CV] END max_depth=2, max_features=5, min_samples_split=7, n_estimators=100; total time=   0.8s
# [CV] END max_depth=2, max_features=5, min_samples_split=7, n_estimators=100; total time=   0.9s
# [CV] END max_depth=2, max_features=5, min_samples_split=5, n_estimators=500; total time=   2.5s
# [CV] END max_depth=2, max_features=5, min_samples_split=5, n_estimators=500; total time=   2.5s
# [CV] END max_depth=2, max_features=5, min_samples_split=5, n_estimators=500; total time=   2.5s
# [CV] END max_depth=2, max_features=5, min_samples_split=5, n_estimators=500; total time=   2.6s
# [CV] END max_depth=2, max_features=5, min_samples_split=7, n_estimators=100; total time=   0.8s
# [CV] END max_depth=2, max_features=5, min_samples_split=6, n_estimators=300; total time=   1.7s
# [CV] END max_depth=2, max_features=5, min_samples_split=6, n_estimators=300; total time=   1.6s
# [CV] END max_depth=2, max_features=5, min_samples_split=7, n_estimators=100; total time=   0.8s
# [CV] END max_depth=2, max_features=5, min_samples_split=6, n_estimators=300; total time=   1.8s
# [CV] END max_depth=2, max_features=5, min_samples_split=6, n_estimators=300; total time=   1.6s
# [CV] END max_depth=2, max_features=5, min_samples_split=7, n_estimators=100; total time=   1.1s
# [CV] END max_depth=2, max_features=5, min_samples_split=9, n_estimators=100; total time=   0.8s
# [CV] END max_depth=2, max_features=5, min_samples_split=9, n_estimators=100; total time=   1.1s
# [CV] END max_depth=2, max_features=5, min_samples_split=9, n_estimators=100; total time=   1.3s
# [CV] END max_depth=2, max_features=5, min_samples_split=7, n_estimators=300; total time=   1.7s
# [CV] END max_depth=2, max_features=5, min_samples_split=9, n_estimators=100; total time=   0.9s
# [CV] END max_depth=2, max_features=5, min_samples_split=6, n_estimators=500; total time=   2.5s
# [CV] END max_depth=2, max_features=5, min_samples_split=6, n_estimators=500; total time=   2.6s
# [CV] END max_depth=2, max_features=5, min_samples_split=6, n_estimators=500; total time=   2.7s
# [CV] END max_depth=2, max_features=5, min_samples_split=6, n_estimators=500; total time=   2.6s
# [CV] END max_depth=2, max_features=5, min_samples_split=7, n_estimators=300; total time=   1.7s
# [CV] END max_depth=2, max_features=5, min_samples_split=7, n_estimators=300; total time=   1.7s
# [CV] END max_depth=2, max_features=5, min_samples_split=7, n_estimators=300; total time=   1.8s
# [CV] END max_depth=2, max_features=5, min_samples_split=6, n_estimators=500; total time=   2.7s
# [CV] END max_depth=2, max_features=5, min_samples_split=9, n_estimators=100; total time=   1.2s
# [CV] END max_depth=2, max_features=5, min_samples_split=7, n_estimators=300; total time=   1.9s
# [CV] END max_depth=2, max_features=5, min_samples_split=7, n_estimators=500; total time=   2.5s
# [CV] END max_depth=2, max_features=5, min_samples_split=7, n_estimators=500; total time=   2.4s
# [CV] END max_depth=5, max_features=2, min_samples_split=2, n_estimators=100; total time=   0.8s
# [CV] END max_depth=2, max_features=5, min_samples_split=7, n_estimators=500; total time=   2.5s
# [CV] END max_depth=5, max_features=2, min_samples_split=2, n_estimators=100; total time=   0.9s
# [CV] END max_depth=2, max_features=5, min_samples_split=9, n_estimators=300; total time=   1.7s
# [CV] END max_depth=2, max_features=5, min_samples_split=7, n_estimators=500; total time=   2.6s
# [CV] END max_depth=5, max_features=2, min_samples_split=2, n_estimators=100; total time=   0.9s
# [CV] END max_depth=5, max_features=2, min_samples_split=2, n_estimators=100; total time=   0.9s
# [CV] END max_depth=2, max_features=5, min_samples_split=9, n_estimators=300; total time=   1.4s
# [CV] END max_depth=5, max_features=2, min_samples_split=2, n_estimators=100; total time=   0.8s
# [CV] END max_depth=2, max_features=5, min_samples_split=9, n_estimators=300; total time=   1.3s
# [CV] END max_depth=2, max_features=5, min_samples_split=7, n_estimators=500; total time=   2.8s
# [CV] END max_depth=2, max_features=5, min_samples_split=9, n_estimators=300; total time=   1.5s
# [CV] END max_depth=2, max_features=5, min_samples_split=9, n_estimators=300; total time=   1.5s
# [CV] END max_depth=5, max_features=2, min_samples_split=3, n_estimators=100; total time=   0.7s
# [CV] END max_depth=5, max_features=2, min_samples_split=3, n_estimators=100; total time=   0.8s
# [CV] END max_depth=5, max_features=2, min_samples_split=3, n_estimators=100; total time=   0.9s
# [CV] END max_depth=5, max_features=2, min_samples_split=3, n_estimators=100; total time=   0.9s
# [CV] END max_depth=2, max_features=5, min_samples_split=9, n_estimators=500; total time=   2.4s
# [CV] END max_depth=2, max_features=5, min_samples_split=9, n_estimators=500; total time=   2.6s
# [CV] END max_depth=2, max_features=5, min_samples_split=9, n_estimators=500; total time=   2.5s
# [CV] END max_depth=2, max_features=5, min_samples_split=9, n_estimators=500; total time=   2.6s
# [CV] END max_depth=2, max_features=5, min_samples_split=9, n_estimators=500; total time=   2.5s
# [CV] END max_depth=5, max_features=2, min_samples_split=2, n_estimators=300; total time=   1.7s
# [CV] END max_depth=5, max_features=2, min_samples_split=3, n_estimators=100; total time=   1.4s
# [CV] END max_depth=5, max_features=2, min_samples_split=2, n_estimators=300; total time=   1.7s
# [CV] END max_depth=5, max_features=2, min_samples_split=2, n_estimators=300; total time=   1.9s
# [CV] END max_depth=5, max_features=2, min_samples_split=2, n_estimators=300; total time=   1.8s
# [CV] END max_depth=5, max_features=2, min_samples_split=2, n_estimators=300; total time=   1.8s
# [CV] END max_depth=5, max_features=2, min_samples_split=2, n_estimators=500; total time=   2.2s
# [CV] END max_depth=5, max_features=2, min_samples_split=2, n_estimators=500; total time=   2.3s
# [CV] END max_depth=5, max_features=2, min_samples_split=5, n_estimators=100; total time=   0.8s
# [CV] END max_depth=5, max_features=2, min_samples_split=5, n_estimators=100; total time=   0.7s
# [CV] END max_depth=5, max_features=2, min_samples_split=2, n_estimators=500; total time=   2.5s
# [CV] END max_depth=5, max_features=2, min_samples_split=5, n_estimators=100; total time=   0.7s
# [CV] END max_depth=5, max_features=2, min_samples_split=3, n_estimators=300; total time=   1.6s
# [CV] END max_depth=5, max_features=2, min_samples_split=3, n_estimators=300; total time=   1.4s
# [CV] END max_depth=5, max_features=2, min_samples_split=5, n_estimators=100; total time=   0.9s
# [CV] END max_depth=5, max_features=2, min_samples_split=5, n_estimators=100; total time=   0.8s
# [CV] END max_depth=5, max_features=2, min_samples_split=2, n_estimators=500; total time=   2.6s
# [CV] END max_depth=5, max_features=2, min_samples_split=3, n_estimators=300; total time=   1.9s
# [CV] END max_depth=5, max_features=2, min_samples_split=3, n_estimators=300; total time=   1.3s
# [CV] END max_depth=5, max_features=2, min_samples_split=3, n_estimators=300; total time=   1.5s
# [CV] END max_depth=5, max_features=2, min_samples_split=2, n_estimators=500; total time=   3.0s
# [CV] END max_depth=5, max_features=2, min_samples_split=6, n_estimators=100; total time=   0.5s
# [CV] END max_depth=5, max_features=2, min_samples_split=6, n_estimators=100; total time=   0.8s
# [CV] END max_depth=5, max_features=2, min_samples_split=6, n_estimators=100; total time=   1.1s
# [CV] END max_depth=5, max_features=2, min_samples_split=5, n_estimators=300; total time=   1.7s
# [CV] END max_depth=5, max_features=2, min_samples_split=6, n_estimators=100; total time=   1.2s
# [CV] END max_depth=5, max_features=2, min_samples_split=6, n_estimators=100; total time=   1.1s
# [CV] END max_depth=5, max_features=2, min_samples_split=5, n_estimators=300; total time=   1.8s
# [CV] END max_depth=5, max_features=2, min_samples_split=3, n_estimators=500; total time=   2.7s
# [CV] END max_depth=5, max_features=2, min_samples_split=5, n_estimators=300; total time=   1.7s
# [CV] END max_depth=5, max_features=2, min_samples_split=3, n_estimators=500; total time=   2.8s
# [CV] END max_depth=5, max_features=2, min_samples_split=5, n_estimators=300; total time=   1.8s
# [CV] END max_depth=5, max_features=2, min_samples_split=3, n_estimators=500; total time=   2.8s
# [CV] END max_depth=5, max_features=2, min_samples_split=3, n_estimators=500; total time=   2.7s
# [CV] END max_depth=5, max_features=2, min_samples_split=3, n_estimators=500; total time=   2.8s
# [CV] END max_depth=5, max_features=2, min_samples_split=5, n_estimators=300; total time=   2.0s
# [CV] END max_depth=5, max_features=2, min_samples_split=5, n_estimators=500; total time=   2.1s
# [CV] END max_depth=5, max_features=2, min_samples_split=7, n_estimators=100; total time=   0.7s
# [CV] END max_depth=5, max_features=2, min_samples_split=5, n_estimators=500; total time=   2.4s
# [CV] END max_depth=5, max_features=2, min_samples_split=7, n_estimators=100; total time=   0.7s
# [CV] END max_depth=5, max_features=2, min_samples_split=7, n_estimators=100; total time=   0.8s
# [CV] END max_depth=5, max_features=2, min_samples_split=7, n_estimators=100; total time=   0.8s
# [CV] END max_depth=5, max_features=2, min_samples_split=6, n_estimators=300; total time=   1.3s
# [CV] END max_depth=5, max_features=2, min_samples_split=6, n_estimators=300; total time=   2.0s
# [CV] END max_depth=5, max_features=2, min_samples_split=5, n_estimators=500; total time=   2.8s
# [CV] END max_depth=5, max_features=2, min_samples_split=5, n_estimators=500; total time=   2.8s
# [CV] END max_depth=5, max_features=2, min_samples_split=6, n_estimators=300; total time=   1.9s
# [CV] END max_depth=5, max_features=2, min_samples_split=5, n_estimators=500; total time=   2.9s
# [CV] END max_depth=5, max_features=2, min_samples_split=6, n_estimators=300; total time=   1.5s
# [CV] END max_depth=5, max_features=2, min_samples_split=7, n_estimators=100; total time=   1.0s
# [CV] END max_depth=5, max_features=2, min_samples_split=6, n_estimators=300; total time=   1.6s
# [CV] END max_depth=5, max_features=2, min_samples_split=7, n_estimators=300; total time=   1.7s
# [CV] END max_depth=5, max_features=2, min_samples_split=9, n_estimators=100; total time=   1.0s
# [CV] END max_depth=5, max_features=2, min_samples_split=9, n_estimators=100; total time=   1.0s
# [CV] END max_depth=5, max_features=2, min_samples_split=9, n_estimators=100; total time=   0.9s
# [CV] END max_depth=5, max_features=2, min_samples_split=7, n_estimators=300; total time=   1.5s
# [CV] END max_depth=5, max_features=2, min_samples_split=9, n_estimators=100; total time=   1.1s
# [CV] END max_depth=5, max_features=2, min_samples_split=9, n_estimators=100; total time=   1.0s
# [CV] END max_depth=5, max_features=2, min_samples_split=7, n_estimators=300; total time=   1.7s
# [CV] END max_depth=5, max_features=2, min_samples_split=6, n_estimators=500; total time=   2.5s
# [CV] END max_depth=5, max_features=2, min_samples_split=6, n_estimators=500; total time=   2.8s
# [CV] END max_depth=5, max_features=2, min_samples_split=7, n_estimators=300; total time=   2.1s
# [CV] END max_depth=5, max_features=2, min_samples_split=6, n_estimators=500; total time=   3.0s
# [CV] END max_depth=5, max_features=2, min_samples_split=6, n_estimators=500; total time=   3.0s
# [CV] END max_depth=5, max_features=2, min_samples_split=6, n_estimators=500; total time=   3.1s
# [CV] END max_depth=5, max_features=2, min_samples_split=7, n_estimators=300; total time=   2.2s
# [CV] END max_depth=5, max_features=2, min_samples_split=7, n_estimators=500; total time=   2.5s
# [CV] END max_depth=5, max_features=2, min_samples_split=7, n_estimators=500; total time=   2.5s
# [CV] END max_depth=5, max_features=2, min_samples_split=7, n_estimators=500; total time=   2.7s
# [CV] END max_depth=5, max_features=3, min_samples_split=2, n_estimators=100; total time=   0.8s
# [CV] END max_depth=5, max_features=3, min_samples_split=2, n_estimators=100; total time=   0.9s
# [CV] END max_depth=5, max_features=2, min_samples_split=9, n_estimators=300; total time=   1.5s
# [CV] END max_depth=5, max_features=3, min_samples_split=2, n_estimators=100; total time=   0.8s
# [CV] END max_depth=5, max_features=2, min_samples_split=9, n_estimators=300; total time=   1.6s
# [CV] END max_depth=5, max_features=2, min_samples_split=7, n_estimators=500; total time=   2.6s
# [CV] END max_depth=5, max_features=2, min_samples_split=7, n_estimators=500; total time=   2.8s
# [CV] END max_depth=5, max_features=3, min_samples_split=2, n_estimators=100; total time=   0.8s
# [CV] END max_depth=5, max_features=2, min_samples_split=9, n_estimators=300; total time=   1.7s
# [CV] END max_depth=5, max_features=3, min_samples_split=2, n_estimators=100; total time=   0.8s
# [CV] END max_depth=5, max_features=2, min_samples_split=9, n_estimators=300; total time=   1.7s
# [CV] END max_depth=5, max_features=2, min_samples_split=9, n_estimators=300; total time=   2.0s
# [CV] END max_depth=5, max_features=3, min_samples_split=3, n_estimators=100; total time=   1.0s
# [CV] END max_depth=5, max_features=2, min_samples_split=9, n_estimators=500; total time=   2.7s
# [CV] END max_depth=5, max_features=2, min_samples_split=9, n_estimators=500; total time=   2.8s
# [CV] END max_depth=5, max_features=3, min_samples_split=3, n_estimators=100; total time=   1.2s
# [CV] END max_depth=5, max_features=3, min_samples_split=3, n_estimators=100; total time=   1.4s
# [CV] END max_depth=5, max_features=3, min_samples_split=3, n_estimators=100; total time=   1.4s
# [CV] END max_depth=5, max_features=3, min_samples_split=2, n_estimators=300; total time=   1.7s
# [CV] END max_depth=5, max_features=2, min_samples_split=9, n_estimators=500; total time=   3.0s
# [CV] END max_depth=5, max_features=2, min_samples_split=9, n_estimators=500; total time=   3.1s
# [CV] END max_depth=5, max_features=3, min_samples_split=2, n_estimators=300; total time=   2.1s
# [CV] END max_depth=5, max_features=3, min_samples_split=3, n_estimators=100; total time=   1.6s
# [CV] END max_depth=5, max_features=3, min_samples_split=2, n_estimators=300; total time=   2.1s
# [CV] END max_depth=5, max_features=3, min_samples_split=2, n_estimators=300; total time=   2.0s
# [CV] END max_depth=5, max_features=2, min_samples_split=9, n_estimators=500; total time=   3.3s
# [CV] END max_depth=5, max_features=3, min_samples_split=2, n_estimators=300; total time=   2.4s
# [CV] END max_depth=5, max_features=3, min_samples_split=2, n_estimators=500; total time=   2.7s
# [CV] END max_depth=5, max_features=3, min_samples_split=5, n_estimators=100; total time=   1.0s
# [CV] END max_depth=5, max_features=3, min_samples_split=5, n_estimators=100; total time=   1.3s
# [CV] END max_depth=5, max_features=3, min_samples_split=2, n_estimators=500; total time=   3.1s
# [CV] END max_depth=5, max_features=3, min_samples_split=2, n_estimators=500; total time=   3.1s
# [CV] END max_depth=5, max_features=3, min_samples_split=5, n_estimators=100; total time=   1.2s
# [CV] END max_depth=5, max_features=3, min_samples_split=2, n_estimators=500; total time=   3.2s
# [CV] END max_depth=5, max_features=3, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END max_depth=5, max_features=3, min_samples_split=3, n_estimators=300; total time=   1.8s
# [CV] END max_depth=5, max_features=3, min_samples_split=2, n_estimators=500; total time=   3.2s
# [CV] END max_depth=5, max_features=3, min_samples_split=3, n_estimators=300; total time=   2.1s
# [CV] END max_depth=5, max_features=3, min_samples_split=3, n_estimators=300; total time=   2.1s
# [CV] END max_depth=5, max_features=3, min_samples_split=3, n_estimators=300; total time=   2.2s
# [CV] END max_depth=5, max_features=3, min_samples_split=5, n_estimators=100; total time=   1.0s
# [CV] END max_depth=5, max_features=3, min_samples_split=3, n_estimators=300; total time=   2.0s
# [CV] END max_depth=5, max_features=3, min_samples_split=6, n_estimators=100; total time=   1.0s
# [CV] END max_depth=5, max_features=3, min_samples_split=6, n_estimators=100; total time=   1.0s
# [CV] END max_depth=5, max_features=3, min_samples_split=6, n_estimators=100; total time=   1.2s
# [CV] END max_depth=5, max_features=3, min_samples_split=6, n_estimators=100; total time=   1.3s
# [CV] END max_depth=5, max_features=3, min_samples_split=6, n_estimators=100; total time=   1.5s
# [CV] END max_depth=5, max_features=3, min_samples_split=3, n_estimators=500; total time=   3.4s
# [CV] END max_depth=5, max_features=3, min_samples_split=3, n_estimators=500; total time=   3.2s
# [CV] END max_depth=5, max_features=3, min_samples_split=5, n_estimators=300; total time=   2.3s
# [CV] END max_depth=5, max_features=3, min_samples_split=5, n_estimators=300; total time=   2.1s
# [CV] END max_depth=5, max_features=3, min_samples_split=5, n_estimators=300; total time=   2.0s
# [CV] END max_depth=5, max_features=3, min_samples_split=3, n_estimators=500; total time=   3.4s
# [CV] END max_depth=5, max_features=3, min_samples_split=5, n_estimators=300; total time=   2.2s
# [CV] END max_depth=5, max_features=3, min_samples_split=3, n_estimators=500; total time=   3.6s
# [CV] END max_depth=5, max_features=3, min_samples_split=5, n_estimators=300; total time=   2.3s
# [CV] END max_depth=5, max_features=3, min_samples_split=3, n_estimators=500; total time=   3.8s
# [CV] END max_depth=5, max_features=3, min_samples_split=5, n_estimators=500; total time=   2.8s
# [CV] END max_depth=5, max_features=3, min_samples_split=7, n_estimators=100; total time=   1.1s
# [CV] END max_depth=5, max_features=3, min_samples_split=7, n_estimators=100; total time=   1.0s
# [CV] END max_depth=5, max_features=3, min_samples_split=5, n_estimators=500; total time=   3.3s
# ...
# [CV] END max_depth=None, max_features=4, min_samples_split=2, n_estimators=500; total time=   9.3s
# [CV] END max_depth=None, max_features=4, min_samples_split=3, n_estimators=300; total time=   5.6s
# [CV] END max_depth=None, max_features=4, min_samples_split=2, n_estimators=500; total time=   9.4s
# [CV] END max_depth=None, max_features=4, min_samples_split=3, n_estimators=300; total time=   5.7s
# [CV] END max_depth=None, max_features=4, min_samples_split=2, n_estimators=500; total time=   9.6s
# [CV] END max_depth=None, max_features=4, min_samples_split=2, n_estimators=500; total time=  10.0s
# [CV] END max_depth=None, max_features=4, min_samples_split=3, n_estimators=300; total time=   6.1s
# [CV] END max_depth=None, max_features=4, min_samples_split=2, n_estimators=500; total time=  10.8s
# [CV] END max_depth=None, max_features=4, min_samples_split=3, n_estimators=300; total time=   6.9s
# [CV] END max_depth=None, max_features=4, min_samples_split=6, n_estimators=100; total time=   3.2s
# [CV] END max_depth=None, max_features=4, min_samples_split=6, n_estimators=100; total time=   3.0s
# [CV] END max_depth=None, max_features=4, min_samples_split=5, n_estimators=300; total time=   4.7s
# [CV] END max_depth=None, max_features=4, min_samples_split=6, n_estimators=100; total time=   2.5s
# [CV] END max_depth=None, max_features=4, min_samples_split=6, n_estimators=100; total time=   4.2s
# [CV] END max_depth=None, max_features=4, min_samples_split=3, n_estimators=500; total time=   9.3s
# [CV] END max_depth=None, max_features=4, min_samples_split=5, n_estimators=300; total time=   5.2s
# [CV] END max_depth=None, max_features=4, min_samples_split=3, n_estimators=500; total time=   9.1s
# [CV] END max_depth=None, max_features=4, min_samples_split=5, n_estimators=300; total time=   5.6s
# [CV] END max_depth=None, max_features=4, min_samples_split=5, n_estimators=300; total time=   5.5s
# [CV] END max_depth=None, max_features=4, min_samples_split=3, n_estimators=500; total time=   9.4s
# [CV] END max_depth=None, max_features=4, min_samples_split=6, n_estimators=100; total time=   3.9s
# [CV] END max_depth=None, max_features=4, min_samples_split=3, n_estimators=500; total time=   9.8s
# [CV] END max_depth=None, max_features=4, min_samples_split=3, n_estimators=500; total time=  10.1s
# [CV] END max_depth=None, max_features=4, min_samples_split=5, n_estimators=300; total time=   6.8s
# [CV] END max_depth=None, max_features=4, min_samples_split=7, n_estimators=100; total time=   3.4s
# [CV] END max_depth=None, max_features=4, min_samples_split=7, n_estimators=100; total time=   3.5s
# [CV] END max_depth=None, max_features=4, min_samples_split=7, n_estimators=100; total time=   3.3s
# [CV] END max_depth=None, max_features=4, min_samples_split=7, n_estimators=100; total time=   3.4s
# [CV] END max_depth=None, max_features=4, min_samples_split=7, n_estimators=100; total time=   3.3s
# [CV] END max_depth=None, max_features=4, min_samples_split=5, n_estimators=500; total time=   9.5s
# [CV] END max_depth=None, max_features=4, min_samples_split=5, n_estimators=500; total time=   9.5s
# [CV] END max_depth=None, max_features=4, min_samples_split=5, n_estimators=500; total time=   9.4s
# [CV] END max_depth=None, max_features=4, min_samples_split=5, n_estimators=500; total time=   9.2s
# [CV] END max_depth=None, max_features=4, min_samples_split=6, n_estimators=300; total time=   5.3s
# [CV] END max_depth=None, max_features=4, min_samples_split=6, n_estimators=300; total time=   5.8s
# [CV] END max_depth=None, max_features=4, min_samples_split=6, n_estimators=300; total time=   5.4s
# [CV] END max_depth=None, max_features=4, min_samples_split=6, n_estimators=300; total time=   5.2s
# [CV] END max_depth=None, max_features=4, min_samples_split=5, n_estimators=500; total time=  10.2s
# [CV] END max_depth=None, max_features=4, min_samples_split=6, n_estimators=300; total time=   6.1s
# [CV] END max_depth=None, max_features=4, min_samples_split=9, n_estimators=100; total time=   2.4s
# [CV] END max_depth=None, max_features=4, min_samples_split=9, n_estimators=100; total time=   2.8s
# [CV] END max_depth=None, max_features=4, min_samples_split=9, n_estimators=100; total time=   3.2s
# [CV] END max_depth=None, max_features=4, min_samples_split=9, n_estimators=100; total time=   3.1s
# [CV] END max_depth=None, max_features=4, min_samples_split=9, n_estimators=100; total time=   3.8s
# [CV] END max_depth=None, max_features=4, min_samples_split=7, n_estimators=300; total time=   5.5s
# [CV] END max_depth=None, max_features=4, min_samples_split=6, n_estimators=500; total time=   9.7s
# [CV] END max_depth=None, max_features=4, min_samples_split=7, n_estimators=300; total time=   5.6s
# [CV] END max_depth=None, max_features=4, min_samples_split=7, n_estimators=300; total time=   6.0s
# [CV] END max_depth=None, max_features=4, min_samples_split=7, n_estimators=300; total time=   5.7s
# [CV] END max_depth=None, max_features=4, min_samples_split=6, n_estimators=500; total time=  10.1s
# [CV] END max_depth=None, max_features=4, min_samples_split=6, n_estimators=500; total time=   9.9s
# [CV] END max_depth=None, max_features=4, min_samples_split=6, n_estimators=500; total time=   9.9s
# [CV] END max_depth=None, max_features=4, min_samples_split=6, n_estimators=500; total time=  10.2s
# [CV] END max_depth=None, max_features=4, min_samples_split=7, n_estimators=300; total time=   6.4s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=100; total time=   3.1s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=100; total time=   3.1s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=100; total time=   3.5s
# [CV] END max_depth=None, max_features=4, min_samples_split=9, n_estimators=300; total time=   6.2s
# [CV] END max_depth=None, max_features=4, min_samples_split=9, n_estimators=300; total time=   6.6s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=100; total time=   3.3s
# [CV] END max_depth=None, max_features=4, min_samples_split=7, n_estimators=500; total time=   9.4s
# [CV] END max_depth=None, max_features=4, min_samples_split=9, n_estimators=300; total time=   5.1s
# [CV] END max_depth=None, max_features=4, min_samples_split=9, n_estimators=300; total time=   6.1s
# [CV] END max_depth=None, max_features=4, min_samples_split=7, n_estimators=500; total time=   9.6s
# [CV] END max_depth=None, max_features=4, min_samples_split=7, n_estimators=500; total time=   9.6s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=100; total time=   3.6s
# [CV] END max_depth=None, max_features=4, min_samples_split=7, n_estimators=500; total time=  10.5s
# [CV] END max_depth=None, max_features=4, min_samples_split=7, n_estimators=500; total time=  11.2s
# [CV] END max_depth=None, max_features=4, min_samples_split=9, n_estimators=300; total time=   7.8s
# [CV] END max_depth=None, max_features=5, min_samples_split=3, n_estimators=100; total time=   3.9s
# [CV] END max_depth=None, max_features=5, min_samples_split=3, n_estimators=100; total time=   4.6s
# [CV] END max_depth=None, max_features=5, min_samples_split=3, n_estimators=100; total time=   4.1s
# [CV] END max_depth=None, max_features=4, min_samples_split=9, n_estimators=500; total time=   9.8s
# [CV] END max_depth=None, max_features=4, min_samples_split=9, n_estimators=500; total time=  10.2s
# [CV] END max_depth=None, max_features=4, min_samples_split=9, n_estimators=500; total time=   9.8s
# [CV] END max_depth=None, max_features=4, min_samples_split=9, n_estimators=500; total time=  10.0s
# [CV] END max_depth=None, max_features=5, min_samples_split=3, n_estimators=100; total time=   4.2s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=300; total time=   6.5s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=300; total time=   6.9s
# [CV] END max_depth=None, max_features=4, min_samples_split=9, n_estimators=500; total time=  10.8s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=300; total time=   6.8s
# [CV] END max_depth=None, max_features=5, min_samples_split=3, n_estimators=100; total time=   4.0s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=300; total time=   7.3s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=300; total time=   7.7s
# [CV] END max_depth=None, max_features=5, min_samples_split=5, n_estimators=100; total time=   4.0s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=500; total time=  10.8s
# [CV] END max_depth=None, max_features=5, min_samples_split=5, n_estimators=100; total time=   3.8s
# [CV] END max_depth=None, max_features=5, min_samples_split=5, n_estimators=100; total time=   4.5s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=500; total time=  11.3s
# [CV] END max_depth=None, max_features=5, min_samples_split=5, n_estimators=100; total time=   4.1s
# [CV] END max_depth=None, max_features=5, min_samples_split=5, n_estimators=100; total time=   4.4s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=500; total time=  11.3s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=500; total time=  11.5s
# [CV] END max_depth=None, max_features=5, min_samples_split=3, n_estimators=300; total time=   7.5s
# [CV] END max_depth=None, max_features=5, min_samples_split=3, n_estimators=300; total time=   7.0s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=500; total time=  12.0s
# [CV] END max_depth=None, max_features=5, min_samples_split=3, n_estimators=300; total time=   6.5s
# [CV] END max_depth=None, max_features=5, min_samples_split=3, n_estimators=300; total time=   6.8s
# [CV] END max_depth=None, max_features=5, min_samples_split=3, n_estimators=300; total time=   7.4s
# [CV] END max_depth=None, max_features=5, min_samples_split=6, n_estimators=100; total time=   3.6s
# [CV] END max_depth=None, max_features=5, min_samples_split=6, n_estimators=100; total time=   4.2s
# [CV] END max_depth=None, max_features=5, min_samples_split=6, n_estimators=100; total time=   4.5s
# [CV] END max_depth=None, max_features=5, min_samples_split=6, n_estimators=100; total time=   4.5s
# [CV] END max_depth=None, max_features=5, min_samples_split=6, n_estimators=100; total time=   4.7s
# [CV] END max_depth=None, max_features=5, min_samples_split=5, n_estimators=300; total time=   7.0s
# [CV] END max_depth=None, max_features=5, min_samples_split=3, n_estimators=500; total time=  11.5s
# [CV] END max_depth=None, max_features=5, min_samples_split=3, n_estimators=500; total time=  11.9s
# [CV] END max_depth=None, max_features=5, min_samples_split=3, n_estimators=500; total time=  11.5s
# [CV] END max_depth=None, max_features=5, min_samples_split=5, n_estimators=300; total time=   7.3s
# [CV] END max_depth=None, max_features=5, min_samples_split=5, n_estimators=300; total time=   7.3s
# [CV] END max_depth=None, max_features=5, min_samples_split=3, n_estimators=500; total time=  12.3s
# [CV] END max_depth=None, max_features=5, min_samples_split=5, n_estimators=300; total time=   7.6s
# [CV] END max_depth=None, max_features=5, min_samples_split=3, n_estimators=500; total time=  12.5s
# [CV] END max_depth=None, max_features=5, min_samples_split=5, n_estimators=300; total time=   8.1s
# [CV] END max_depth=None, max_features=5, min_samples_split=7, n_estimators=100; total time=   3.9s
# [CV] END max_depth=None, max_features=5, min_samples_split=7, n_estimators=100; total time=   3.9s
# [CV] END max_depth=None, max_features=5, min_samples_split=7, n_estimators=100; total time=   4.2s
# [CV] END max_depth=None, max_features=5, min_samples_split=7, n_estimators=100; total time=   4.0s
# [CV] END max_depth=None, max_features=5, min_samples_split=5, n_estimators=500; total time=  11.4s
# [CV] END max_depth=None, max_features=5, min_samples_split=6, n_estimators=300; total time=   7.3s
# [CV] END max_depth=None, max_features=5, min_samples_split=7, n_estimators=100; total time=   3.8s
# [CV] END max_depth=None, max_features=5, min_samples_split=5, n_estimators=500; total time=  11.6s
# [CV] END max_depth=None, max_features=5, min_samples_split=5, n_estimators=500; total time=  11.7s
# [CV] END max_depth=None, max_features=5, min_samples_split=6, n_estimators=300; total time=   7.0s
# [CV] END max_depth=None, max_features=5, min_samples_split=6, n_estimators=300; total time=   6.6s
# [CV] END max_depth=None, max_features=5, min_samples_split=5, n_estimators=500; total time=  11.8s
# [CV] END max_depth=None, max_features=5, min_samples_split=5, n_estimators=500; total time=  12.1s
# [CV] END max_depth=None, max_features=5, min_samples_split=6, n_estimators=300; total time=   7.2s
# [CV] END max_depth=None, max_features=5, min_samples_split=6, n_estimators=300; total time=   7.3s
# [CV] END max_depth=None, max_features=5, min_samples_split=9, n_estimators=100; total time=   4.0s
# [CV] END max_depth=None, max_features=5, min_samples_split=9, n_estimators=100; total time=   3.7s
# [CV] END max_depth=None, max_features=5, min_samples_split=9, n_estimators=100; total time=   4.6s
# [CV] END max_depth=None, max_features=5, min_samples_split=9, n_estimators=100; total time=   4.8s
# [CV] END max_depth=None, max_features=5, min_samples_split=7, n_estimators=300; total time=   6.9s
# [CV] END max_depth=None, max_features=5, min_samples_split=7, n_estimators=300; total time=   6.8s
# [CV] END max_depth=None, max_features=5, min_samples_split=6, n_estimators=500; total time=  11.5s
# [CV] END max_depth=None, max_features=5, min_samples_split=6, n_estimators=500; total time=  11.8s
# [CV] END max_depth=None, max_features=5, min_samples_split=9, n_estimators=100; total time=   4.7s
# [CV] END max_depth=None, max_features=5, min_samples_split=6, n_estimators=500; total time=  11.6s
# [CV] END max_depth=None, max_features=5, min_samples_split=6, n_estimators=500; total time=  12.0s
# [CV] END max_depth=None, max_features=5, min_samples_split=7, n_estimators=300; total time=   6.8s
# [CV] END max_depth=None, max_features=5, min_samples_split=7, n_estimators=300; total time=   6.8s
# [CV] END max_depth=None, max_features=5, min_samples_split=7, n_estimators=300; total time=   7.1s
# [CV] END max_depth=None, max_features=5, min_samples_split=6, n_estimators=500; total time=  12.0s
# [CV] END max_depth=None, max_features=5, min_samples_split=7, n_estimators=500; total time=   9.9s
# [CV] END max_depth=None, max_features=5, min_samples_split=7, n_estimators=500; total time=  10.6s
# [CV] END max_depth=None, max_features=5, min_samples_split=7, n_estimators=500; total time=  10.8s
# [CV] END max_depth=None, max_features=5, min_samples_split=9, n_estimators=300; total time=   6.5s
# [CV] END max_depth=None, max_features=5, min_samples_split=7, n_estimators=500; total time=  11.0s
# [CV] END max_depth=None, max_features=5, min_samples_split=7, n_estimators=500; total time=  11.0s
# [CV] END max_depth=None, max_features=5, min_samples_split=9, n_estimators=300; total time=   6.4s
# [CV] END max_depth=None, max_features=5, min_samples_split=9, n_estimators=300; total time=   5.9s
# [CV] END max_depth=None, max_features=5, min_samples_split=9, n_estimators=300; total time=   6.5s
# [CV] END max_depth=None, max_features=5, min_samples_split=9, n_estimators=300; total time=   5.9s
# [CV] END max_depth=None, max_features=5, min_samples_split=9, n_estimators=500; total time=   6.8s
# [CV] END max_depth=None, max_features=5, min_samples_split=9, n_estimators=500; total time=   6.8s
# [CV] END max_depth=None, max_features=5, min_samples_split=9, n_estimators=500; total time=   6.8s
# [CV] END max_depth=None, max_features=5, min_samples_split=9, n_estimators=500; total time=   6.9s
# [CV] END max_depth=None, max_features=5, min_samples_split=9, n_estimators=500; total time=   6.8s
# Best params: {'max_depth': None, 'max_features': 4, 'min_samples_split': 7, 'n_estimators': 500}
# Best score: 0.8384533798091967
# Best estimator: RandomForestClassifier(max_features=4, min_samples_split=7, n_estimators=500,
#                        n_jobs=-1)

# %%
### WITH EPOCH ###
# Best params: {'max_depth': 11, 'max_features': None, 'min_samples_split': 2, 'n_estimators': 1000}
# Best score: 0.8482662276106373
# Best estimator: RandomForestClassifier(max_depth=11, max_features=None, n_estimators=1000)

# Best params: {'max_depth': None, 'max_features': 5, 'min_samples_split': 2, 'n_estimators': 100}
# Best score: 0.8491334895465693
# Best estimator: RandomForestClassifier(max_features=5, n_jobs=-1)

### WITHOUT EPOCH ###
# Best params: {'max_depth': None, 'max_features': 5, 'min_samples_split': 3, 'n_estimators': 500}
# Best score: 0.8374993632612666
# Best estimator: RandomForestClassifier(max_features=5, min_samples_split=3, n_estimators=500,
#                        n_jobs=-1)

# best_params = {}
# best_params['n_estimators'] = 1000
# best_params['max_features'] = None
# best_params['max_depth'] = 11
# best_params['min_samples_split'] = 2

# %% [markdown]
# # Random Forest
#
# Un classificatore di foreste casuale.
#
# Una foresta casuale è un metastimatore che adatta una serie di classificatori dell'albero decisionale su vari sottocampioni del set di dati e utilizza la media per migliorare l'accuratezza predittiva e controllare l'adattamento eccessivo.

# %%
# Extracting best hyperparameters
N_ESTIMATORS = best_params['n_estimators'] # The number of trees in the forest
MAX_FEATURE = best_params['max_features'] # The number of features to consider when looking for the best split
MAX_DEPTH = best_params['max_depth'] # The maximum depth of the tree
MIN_SAMPLES_SPLIT = best_params['min_samples_split'] # Minimum number of samples required to split a node into terno
CRITERION = 'gini' # The function to measure the quality of a split

from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=N_ESTIMATORS, criterion=CRITERION, 
                               max_depth=MAX_DEPTH, max_features=MAX_FEATURE,
                               random_state=RANDOM_STATE, class_weight=class_weight_dict, n_jobs=N_JOBS)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight={0.0: 2.383272727272727,
#                                      1.0: 0.6327476346785094},
#                        max_features=4, n_estimators=500, n_jobs=-1,
#                        random_state=42)

# %% [markdown]
# $$
# \text{Accuracy}: \frac{\text{true positives + true negatives}}{\text{true positives + true negatives + false positives + false negatives}}
# $$
#
#
# $$
# \text{F-score}: 2 \cdot \frac{\text{Precision} \cdot \text{Recall}}{\text{Precision} + \text{Recall}}
# $$
#
# $$
# \text{Precision}: \frac{\text{true positives}}{\text{true positives + false positives}}
# $$
#
#
# $$
# \text{Recall}: \frac{\text{true positives}}{\text{true positives + false negatives}}
# $$

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, precision_score, recall_score

predictions = model.predict(X_test)

# Determine performance metrics
cm = confusion_matrix(y_test, predictions)
print('Accuracy:', accuracy_score(y_test, predictions))
print('F1-score:', f1_score(y_test, predictions))
print('Precision:', precision_score(y_test, predictions))
print('Recall:', recall_score(y_test, predictions))
print("cm: ", cm)

# Visualizza la matrice di confusione
sns.heatmap(cm, annot=True, cmap='Blues', fmt='g')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

###### 70% 30% ######
"""
N_ESTIMATORS = 1000
MAX_FEATURE = 'log2'
MAX_DEPTH = None
MIN_SAMPLES_SPLIT = 2
CRITERION = 'entropy'
Accuracy: 83,93%
F1-score: 90,50%
Precision: 84,65%
Recall: 97,22%
cm: [[145, 273][43, 1506]]
"""

"""
N_ESTIMATORS = 1000
MAX_FEATURE = 'log2'
MAX_DEPTH = 30
MIN_SAMPLES_SPLIT = 5
CRITERION = 'entropy'
Accuracy: 83,88%
F1-score: 90,51%
Precision: 84,33%
Recall: 97,67%
cm: [[137, 281][36, 1513]]
"""

"""
N_ESTIMATORS = 1000
MAX_FEATURE = None
MAX_DEPTH = 11
MIN_SAMPLES_SPLIT = 2
CRITERION = 'entropy'
Accuracy: 84,59%
F1-score: 90,56%
Precision: 87,43%
Recall: 93,93%
cm: [[209, 209][94, 1455]]
"""

###### 80% 20% ######
"""
N_ESTIMATORS = 1000
MAX_FEATURE = None
MAX_DEPTH = 11
MIN_SAMPLES_SPLIT = 2
CRITERION = 'entropy'
Accuracy: 85,88%
F1-score: 91,31%
Precision: 88,29%
Recall: 94,55%
cm: [[153, 129][56, 973]]
"""

"""
N_ESTIMATORS = 100
MAX_FEATURE = 5
MAX_DEPTH = None
MIN_SAMPLES_SPLIT = 2
CRITERION = 'entropy'
Accuracy: 83,67%
F1-score: 90,31%
Precision: 84,50%
Recall: 96,98%
cm: [[99, 183][31, 998]]
"""

"""
N_ESTIMATORS = 500
MAX_FEATURE = 5
MAX_DEPTH = None
MIN_SAMPLES_SPLIT = 3
CRITERION = 'entropy'
Accuracy: 82,99%
F1-score: 90,04%
Precision: 83,30%
Recall: 97,95%
cm: [[80, 202][21, 1008]]
"""
# Out:
# Accuracy: 0.8268497330282227
# F1-score: 0.8984340044742729
# Precision: 0.8325041459369817
# Recall: 0.9757045675413022
# cm:  [[  80  202]
#  [  25 1004]]
# "\nN_ESTIMATORS = 500\nMAX_FEATURE = 5\nMAX_DEPTH = None\nMIN_SAMPLES_SPLIT = 3\nCRITERION = 'entropy'\nAccuracy: 82,99%\nF1-score: 90,04%\nPrecision: 83,30%\nRecall: 97,95%\ncm: [[80, 202][21, 1008]]\n"

# %%
print_feature_importance(X_train=X_train, feature_importances_=model.feature_importances_)
# Out:
# 1: TESS Mag----------------------> 0.05125267580587069
# 2: Planet Equil Temp (K)---------> 0.0490569178977791
# 3: Planet Insolation (Earth Flux)> 0.04795142399878361
# 4: Period (days)-----------------> 0.0461041795555628
# 5: Planet Radius (R_Earth) err---> 0.042388681879674664
# 6: Planet Radius (R_Earth)-------> 0.04066082331345389
# 7: Period (days) err-------------> 0.03858245754479344
# 8: TSM---------------------------> 0.03795319574062014
# 9: Duration (hours)--------------> 0.03785336251830443
# 10:ESM---------------------------> 0.03382381770138896
# 11:Stellar Radius (R_Sun)--------> 0.03166860873403067
# 12:Stellar Radius (R_Sun) err----> 0.031117918358890065
# 13:Stellar Distance (pc)---------> 0.03025158310741831
# 14:Depth (mmag)------------------> 0.02911242127339757
# 15:Depth (ppm)-------------------> 0.02910579740140264
# 16:Stellar Mass (M_Sun)----------> 0.028955423807663656
# 17:Stellar Mass (M_Sun) err------> 0.028435963411105318
# 18:Stellar Distance (pc) err-----> 0.02785586551215527
# 19:Stellar log(g) (cm/s^2)-------> 0.02744175797036425
# 20:Duration (hours) err----------> 0.026369967764248596
# 21:Depth (mmag) err--------------> 0.025785449009834913
# 22:Stellar Eff Temp (K)----------> 0.025623065691825046
# 23:PM RA (mas/yr)----------------> 0.02554366591023701
# 24:Planet SNR--------------------> 0.02552992687625417
# 25:PM Dec err (mas/yr)-----------> 0.025389522010106854
# 26:Stellar Eff Temp (K) err------> 0.025110971175381597
# 27:PM RA err (mas/yr)------------> 0.025098971912976102
# 28:Depth (ppm) err---------------> 0.025073407570202308
# 29:Predicted Mass (M_Earth)------> 0.02426141771244127
# 30:Stellar log(g) (cm/s^2) err---> 0.02398342841199602
# 31:PM Dec (mas/yr)---------------> 0.023831676812063187
# 32:TESS Mag err------------------> 0.008825653609773441

# %%
plot_feature_importances(X_train=X_train, feature_importances=model.feature_importances_)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score

# Decision Tree
dt_params = {'max_depth': [None, 10, 20, 30], 'min_samples_split': [2, 5, 10, 11]}
dt_classifier = DecisionTreeClassifier()
dt_grid_search = GridSearchCV(dt_classifier, dt_params, cv=5, n_jobs=N_JOBS, verbose=2)
dt_grid_search.fit(X_train, y_train)

# K-Nearest Neighbors
knn_params = {'n_neighbors': [3, 5, 7, 11, 15, 33]}
knn_classifier = KNeighborsClassifier(n_jobs=N_JOBS)
knn_grid_search = GridSearchCV(knn_classifier, knn_params, cv=5, n_jobs=N_JOBS, verbose=2)
knn_grid_search.fit(X_train, y_train)

# Gradient Boosting
gb_params = {'n_estimators': [50, 100, 200, 500], 'learning_rate': [0.01, 0.1, 0.2, 0.001, 0.4]}
gb_classifier = GradientBoostingClassifier()
gb_grid_search = GridSearchCV(gb_classifier, gb_params, cv=5, n_jobs=N_JOBS, verbose=2)
gb_grid_search.fit(X_train, y_train)

# Print the best parameters for each classifier
print("Best parameters for Decision Tree:", dt_grid_search.best_params_)
print("Best parameters for K-Nearest Neighbors:", knn_grid_search.best_params_)
print("Best parameters for Gradient Boosting:", gb_grid_search.best_params_)

# Make predictions on the test set for each classifier
dt_predictions = dt_grid_search.predict(X_test)
knn_predictions = knn_grid_search.predict(X_test)
gb_predictions = gb_grid_search.predict(X_test)

# Evaluate accuracy for each classifier
dt_accuracy = accuracy_score(y_test, dt_predictions)
knn_accuracy = accuracy_score(y_test, knn_predictions)
gb_accuracy = accuracy_score(y_test, gb_predictions)

print("Accuracy for Decision Tree:", dt_accuracy)
print("Accuracy for K-Nearest Neighbors:", knn_accuracy)
print("Accuracy for Gradient Boosting:", gb_accuracy)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV] END ...............max_depth=None, min_samples_split=10; total time=   0.3s
# [CV] END ...............max_depth=None, min_samples_split=10; total time=   0.3s
# [CV] END ................max_depth=None, min_samples_split=2; total time=   0.3s
# [CV] END ................max_depth=None, min_samples_split=2; total time=   0.4s
# [CV] END ................max_depth=None, min_samples_split=5; total time=   0.4s
# [CV] END ................max_depth=None, min_samples_split=2; total time=   0.4s
# [CV] END ................max_depth=None, min_samples_split=5; total time=   0.3s
# [CV] END ...............max_depth=None, min_samples_split=10; total time=   0.3s
# [CV] END ...............max_depth=None, min_samples_split=10; total time=   0.3s
# [CV] END ...............max_depth=None, min_samples_split=11; total time=   0.3s
# [CV] END ...............max_depth=None, min_samples_split=10; total time=   0.3s
# [CV] END ................max_depth=None, min_samples_split=5; total time=   0.4s
# [CV] END ................max_depth=None, min_samples_split=5; total time=   0.4s
# [CV] END ................max_depth=None, min_samples_split=2; total time=   0.4s
# [CV] END ...............max_depth=None, min_samples_split=11; total time=   0.4s
# [CV] END ...............max_depth=None, min_samples_split=11; total time=   0.4s
# [CV] END ................max_depth=None, min_samples_split=5; total time=   0.4s
# [CV] END ...............max_depth=None, min_samples_split=11; total time=   0.4s
# [CV] END ...............max_depth=None, min_samples_split=11; total time=   0.4s
# [CV] END ..................max_depth=10, min_samples_split=2; total time=   0.2s
# [CV] END ................max_depth=None, min_samples_split=2; total time=   0.5s
# [CV] END ..................max_depth=10, min_samples_split=2; total time=   0.2s
# [CV] END ..................max_depth=10, min_samples_split=2; total time=   0.2s
# [CV] END ..................max_depth=10, min_samples_split=2; total time=   0.2s
# [CV] END ..................max_depth=10, min_samples_split=2; total time=   0.2s
# [CV] END ..................max_depth=10, min_samples_split=5; total time=   0.2s
# [CV] END ..................max_depth=10, min_samples_split=5; total time=   0.2s
# [CV] END ..................max_depth=10, min_samples_split=5; total time=   0.2s
# [CV] END ..................max_depth=10, min_samples_split=5; total time=   0.2s
# [CV] END ..................max_depth=10, min_samples_split=5; total time=   0.2s[CV] END .................max_depth=10, min_samples_split=10; total time=   0.2s
#
# [CV] END .................max_depth=10, min_samples_split=10; total time=   0.2s
# [CV] END .................max_depth=10, min_samples_split=10; total time=   0.2s
# [CV] END .................max_depth=10, min_samples_split=10; total time=   0.2s
# [CV] END .................max_depth=10, min_samples_split=10; total time=   0.2s
# [CV] END .................max_depth=10, min_samples_split=11; total time=   0.2s
# [CV] END .................max_depth=10, min_samples_split=11; total time=   0.2s
# [CV] END .................max_depth=10, min_samples_split=11; total time=   0.2s
# [CV] END .................max_depth=10, min_samples_split=11; total time=   0.2s
# [CV] END .................max_depth=10, min_samples_split=11; total time=   0.2s
# [CV] END ..................max_depth=20, min_samples_split=2; total time=   0.3s
# [CV] END ..................max_depth=20, min_samples_split=2; total time=   0.3s
# [CV] END ..................max_depth=20, min_samples_split=2; total time=   0.3s
# [CV] END ..................max_depth=20, min_samples_split=2; total time=   0.3s
# [CV] END ..................max_depth=20, min_samples_split=5; total time=   0.3s
# [CV] END .................max_depth=20, min_samples_split=10; total time=   0.3s
# [CV] END .................max_depth=20, min_samples_split=11; total time=   0.2s
# [CV] END ..................max_depth=20, min_samples_split=5; total time=   0.3s
# [CV] END ..................max_depth=20, min_samples_split=5; total time=   0.3s
# [CV] END ..................max_depth=20, min_samples_split=2; total time=   0.3s
# [CV] END ..................max_depth=20, min_samples_split=5; total time=   0.3s
# [CV] END ..................max_depth=20, min_samples_split=5; total time=   0.3s
# [CV] END .................max_depth=20, min_samples_split=10; total time=   0.3s
# [CV] END .................max_depth=20, min_samples_split=10; total time=   0.3s
# [CV] END .................max_depth=20, min_samples_split=10; total time=   0.3s
# [CV] END .................max_depth=20, min_samples_split=11; total time=   0.3s
# [CV] END .................max_depth=20, min_samples_split=10; total time=   0.3s
# [CV] END .................max_depth=20, min_samples_split=11; total time=   0.3s
# [CV] END .................max_depth=20, min_samples_split=11; total time=   0.3s
# [CV] END .................max_depth=20, min_samples_split=11; total time=   0.3s
# [CV] END ..................max_depth=30, min_samples_split=2; total time=   0.2s
# [CV] END ..................max_depth=30, min_samples_split=2; total time=   0.3s
# [CV] END ..................max_depth=30, min_samples_split=2; total time=   0.2s
# [CV] END ..................max_depth=30, min_samples_split=5; total time=   0.2s
# [CV] END ..................max_depth=30, min_samples_split=5; total time=   0.3s
# [CV] END ..................max_depth=30, min_samples_split=5; total time=   0.2s
# [CV] END ..................max_depth=30, min_samples_split=2; total time=   0.3s
# [CV] END .................max_depth=30, min_samples_split=10; total time=   0.2s
# [CV] END ..................max_depth=30, min_samples_split=5; total time=   0.3s
# [CV] END .................max_depth=30, min_samples_split=10; total time=   0.3s
# [CV] END ..................max_depth=30, min_samples_split=2; total time=   0.3s
# [CV] END .................max_depth=30, min_samples_split=10; total time=   0.3s
# [CV] END .................max_depth=30, min_samples_split=10; total time=   0.3s
# [CV] END .................max_depth=30, min_samples_split=11; total time=   0.2s
# [CV] END ..................max_depth=30, min_samples_split=5; total time=   0.3s
# [CV] END .................max_depth=30, min_samples_split=10; total time=   0.3s
# [CV] END .................max_depth=30, min_samples_split=11; total time=   0.2s
# [CV] END .................max_depth=30, min_samples_split=11; total time=   0.3s
# [CV] END .................max_depth=30, min_samples_split=11; total time=   0.3s
# [CV] END .................max_depth=30, min_samples_split=11; total time=   0.3s
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV] END ......................................n_neighbors=5; total time=   0.2s
# [CV] END ......................................n_neighbors=3; total time=   0.2s
# [CV] END ......................................n_neighbors=3; total time=   0.2s
# [CV] END ......................................n_neighbors=7; total time=   0.2s
# [CV] END ......................................n_neighbors=7; total time=   0.2s
# [CV] END ......................................n_neighbors=3; total time=   0.2s
# [CV] END ......................................n_neighbors=7; total time=   0.2s
# [CV] END .....................................n_neighbors=11; total time=   0.2s
# [CV] END .....................................n_neighbors=11; total time=   0.2s
# [CV] END ......................................n_neighbors=7; total time=   0.2s
# [CV] END ......................................n_neighbors=5; total time=   0.2s
# [CV] END ......................................n_neighbors=3; total time=   0.2s
# [CV] END ......................................n_neighbors=5; total time=   0.2s
# [CV] END ......................................n_neighbors=7; total time=   0.2s
# [CV] END .....................................n_neighbors=11; total time=   0.2s
# [CV] END ......................................n_neighbors=5; total time=   0.2s
# [CV] END .....................................n_neighbors=15; total time=   0.1s
# [CV] END ......................................n_neighbors=3; total time=   0.2s
# [CV] END .....................................n_neighbors=11; total time=   0.2s
# [CV] END .....................................n_neighbors=11; total time=   0.2s
# [CV] END ......................................n_neighbors=5; total time=   0.2s
# [CV] END .....................................n_neighbors=15; total time=   0.1s
# [CV] END .....................................n_neighbors=15; total time=   0.1s
# [CV] END .....................................n_neighbors=15; total time=   0.1s
# [CV] END .....................................n_neighbors=15; total time=   0.1s
# [CV] END .....................................n_neighbors=33; total time=   0.1s
# [CV] END .....................................n_neighbors=33; total time=   0.1s
# [CV] END .....................................n_neighbors=33; total time=   0.1s
# [CV] END .....................................n_neighbors=33; total time=   0.1s
# [CV] END .....................................n_neighbors=33; total time=   0.1s
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV] END ................learning_rate=0.01, n_estimators=50; total time=   2.6s[CV] END ................learning_rate=0.01, n_estimators=50; total time=   2.6s
#
# [CV] END ................learning_rate=0.01, n_estimators=50; total time=   2.6s
# [CV] END ................learning_rate=0.01, n_estimators=50; total time=   2.7s
# [CV] END ................learning_rate=0.01, n_estimators=50; total time=   2.7s
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time=   4.9s
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time=   4.9s
# [CV] END .................learning_rate=0.1, n_estimators=50; total time=   2.4s
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time=   5.0s
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time=   5.0s
# [CV] END .................learning_rate=0.1, n_estimators=50; total time=   2.5s
# [CV] END .................learning_rate=0.1, n_estimators=50; total time=   2.4s
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time=   5.1s
# [CV] END .................learning_rate=0.1, n_estimators=50; total time=   2.4s
# [CV] END .................learning_rate=0.1, n_estimators=50; total time=   2.6s
# [CV] END ................learning_rate=0.1, n_estimators=100; total time=   4.8s
# [CV] END ...............learning_rate=0.01, n_estimators=200; total time=   9.8s
# [CV] END ...............learning_rate=0.01, n_estimators=200; total time=   9.8s
# [CV] END ................learning_rate=0.1, n_estimators=100; total time=   4.8s
# [CV] END ................learning_rate=0.1, n_estimators=100; total time=   4.9s
# [CV] END ...............learning_rate=0.01, n_estimators=200; total time=   9.9s
# [CV] END ................learning_rate=0.1, n_estimators=100; total time=   4.9s
# [CV] END ...............learning_rate=0.01, n_estimators=200; total time=   9.9s
# [CV] END ................learning_rate=0.1, n_estimators=100; total time=   4.9s
# [CV] END ...............learning_rate=0.01, n_estimators=200; total time=  10.0s
# [CV] END .................learning_rate=0.2, n_estimators=50; total time=   2.4s
# [CV] END .................learning_rate=0.2, n_estimators=50; total time=   2.4s
# [CV] END .................learning_rate=0.2, n_estimators=50; total time=   2.4s
# [CV] END .................learning_rate=0.2, n_estimators=50; total time=   2.5s
# [CV] END .................learning_rate=0.2, n_estimators=50; total time=   2.5s
# [CV] END ................learning_rate=0.1, n_estimators=200; total time=   9.7s
# [CV] END ................learning_rate=0.1, n_estimators=200; total time=   9.7s
# [CV] END ................learning_rate=0.1, n_estimators=200; total time=   9.7s
# [CV] END ................learning_rate=0.1, n_estimators=200; total time=   9.8s
# [CV] END ................learning_rate=0.1, n_estimators=200; total time=  10.0s
# [CV] END ................learning_rate=0.2, n_estimators=100; total time=   4.8s
# [CV] END ................learning_rate=0.2, n_estimators=100; total time=   4.8s
# [CV] END ................learning_rate=0.2, n_estimators=100; total time=   4.9s
# [CV] END ................learning_rate=0.2, n_estimators=100; total time=   5.0s
# [CV] END ................learning_rate=0.2, n_estimators=100; total time=   5.0s
# [CV] END ...............learning_rate=0.01, n_estimators=500; total time=  24.2s
# [CV] END ...............learning_rate=0.01, n_estimators=500; total time=  24.2s
# [CV] END ...............learning_rate=0.01, n_estimators=500; total time=  24.3s
# [CV] END ...............learning_rate=0.01, n_estimators=500; total time=  24.3s
# [CV] END ................learning_rate=0.2, n_estimators=200; total time=   9.7s
# [CV] END ...............learning_rate=0.01, n_estimators=500; total time=  24.6s
# [CV] END ................learning_rate=0.2, n_estimators=200; total time=   9.8s
# [CV] END ................learning_rate=0.2, n_estimators=200; total time=   9.8s
# [CV] END ................learning_rate=0.2, n_estimators=200; total time=   9.7s
# [CV] END ................learning_rate=0.2, n_estimators=200; total time=  10.1s
# [CV] END ...............learning_rate=0.001, n_estimators=50; total time=   2.4s
# [CV] END ...............learning_rate=0.001, n_estimators=50; total time=   2.4s
# [CV] END ...............learning_rate=0.001, n_estimators=50; total time=   2.5s
# [CV] END ...............learning_rate=0.001, n_estimators=50; total time=   2.5s
# [CV] END ...............learning_rate=0.001, n_estimators=50; total time=   2.4s
# [CV] END ..............learning_rate=0.001, n_estimators=100; total time=   4.8s
# [CV] END ..............learning_rate=0.001, n_estimators=100; total time=   4.9s
# [CV] END ..............learning_rate=0.001, n_estimators=100; total time=   4.9s
# [CV] END ..............learning_rate=0.001, n_estimators=100; total time=   4.9s
# [CV] END ..............learning_rate=0.001, n_estimators=100; total time=   5.0s
# [CV] END ................learning_rate=0.1, n_estimators=500; total time=  24.2s
# [CV] END ................learning_rate=0.1, n_estimators=500; total time=  24.2s
# [CV] END ................learning_rate=0.1, n_estimators=500; total time=  24.2s
# [CV] END ................learning_rate=0.1, n_estimators=500; total time=  24.3s
# [CV] END ................learning_rate=0.1, n_estimators=500; total time=  24.2s
# [CV] END ..............learning_rate=0.001, n_estimators=200; total time=   9.7s
# [CV] END .................learning_rate=0.4, n_estimators=50; total time=   2.4s
# [CV] END .................learning_rate=0.4, n_estimators=50; total time=   2.4s
# [CV] END .................learning_rate=0.4, n_estimators=50; total time=   2.4s
# [CV] END ..............learning_rate=0.001, n_estimators=200; total time=   9.9s
# [CV] END .................learning_rate=0.4, n_estimators=50; total time=   2.5s
# [CV] END ..............learning_rate=0.001, n_estimators=200; total time=   9.8s
# [CV] END ..............learning_rate=0.001, n_estimators=200; total time=   9.8s
# [CV] END .................learning_rate=0.4, n_estimators=50; total time=   2.6s
# [CV] END ..............learning_rate=0.001, n_estimators=200; total time=  10.0s
# [CV] END ................learning_rate=0.4, n_estimators=100; total time=   4.8s
# [CV] END ................learning_rate=0.4, n_estimators=100; total time=   4.8s
# [CV] END ................learning_rate=0.4, n_estimators=100; total time=   4.8s
# [CV] END ................learning_rate=0.4, n_estimators=100; total time=   4.9s
# [CV] END ................learning_rate=0.4, n_estimators=100; total time=   4.9s
# [CV] END ................learning_rate=0.2, n_estimators=500; total time=  24.3s
# [CV] END ................learning_rate=0.2, n_estimators=500; total time=  24.5s
# [CV] END ................learning_rate=0.2, n_estimators=500; total time=  24.6s
# [CV] END ................learning_rate=0.2, n_estimators=500; total time=  24.8s
# [CV] END ................learning_rate=0.2, n_estimators=500; total time=  25.2s
# [CV] END ................learning_rate=0.4, n_estimators=200; total time=   9.6s
# [CV] END ................learning_rate=0.4, n_estimators=200; total time=   9.6s
# [CV] END ................learning_rate=0.4, n_estimators=200; total time=   9.7s
# [CV] END ................learning_rate=0.4, n_estimators=200; total time=   9.7s
# [CV] END ................learning_rate=0.4, n_estimators=200; total time=  10.2s
# [CV] END ..............learning_rate=0.001, n_estimators=500; total time=  24.2s
# [CV] END ..............learning_rate=0.001, n_estimators=500; total time=  24.3s
# [CV] END ..............learning_rate=0.001, n_estimators=500; total time=  24.6s
# [CV] END ..............learning_rate=0.001, n_estimators=500; total time=  24.6s
# [CV] END ..............learning_rate=0.001, n_estimators=500; total time=  24.6s
# [CV] END ................learning_rate=0.4, n_estimators=500; total time=  23.1s
# [CV] END ................learning_rate=0.4, n_estimators=500; total time=  23.3s
# [CV] END ................learning_rate=0.4, n_estimators=500; total time=  23.4s
# [CV] END ................learning_rate=0.4, n_estimators=500; total time=  23.4s
# [CV] END ................learning_rate=0.4, n_estimators=500; total time=  23.8s
# Best parameters for Decision Tree: {'max_depth': 10, 'min_samples_split': 2}
# Best parameters for K-Nearest Neighbors: {'n_neighbors': 15}
# Best parameters for Gradient Boosting: {'learning_rate': 0.1, 'n_estimators': 100}
# Accuracy for Decision Tree: 0.8062547673531655
# Accuracy for K-Nearest Neighbors: 0.8108314263920672
# Accuracy for Gradient Boosting: 0.8367658276125095

# %%
### WITH EPOCH ###
# Best parameters for Decision Tree: {'max_depth': 10, 'min_samples_split': 2}
# Best parameters for K-Nearest Neighbors: {'n_neighbors': 7}
# Best parameters for Gradient Boosting: {'learning_rate': 0.2, 'n_estimators': 500}
# Accuracy for Decision Tree: 0.8070175438596491
# Accuracy for K-Nearest Neighbors: 0.816933638443936
# Accuracy for Gradient Boosting: 0.8604118993135011

### WITHOUT EPOCH ###
# Best parameters for Decision Tree: {'max_depth': 10, 'min_samples_split': 2}
# Best parameters for K-Nearest Neighbors: {'n_neighbors': 5}
# Best parameters for Gradient Boosting: {'learning_rate': 0.2, 'n_estimators': 100}
# Accuracy for Decision Tree: 0.7917620137299771
# Accuracy for K-Nearest Neighbors: 0.8062547673531655
# Accuracy for Gradient Boosting: 0.8390541571319603
